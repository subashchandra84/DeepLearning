# %% [markdown]
# # Eye For Blind:
#
# Subash Chandra R

# %%
#Import all the required libraries

import collections
import cv2
#import glob
import json
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import pickle
import random
import re
import tensorflow as tf
import time

#from glob import glob
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from tqdm import tqdm

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
pwd
# Out:
# '/content'

# %% [markdown]
# Let's read the dataset

# %% [markdown]
# ## Data understanding
# 1.Import the dataset and read image & captions into two seperate variables
#
# 2.Visualise both the images & text present in the dataset
#
# 3.Create word-to-index and index-to-word mappings.
#
# 4.Create a dataframe which summarizes the image, path & captions as a dataframe
#
# 5.Visualise the top 30 occuring words in the captions
#
# 6.Create a list which contains all the captions & path

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
#!kaggle kernels output tripsankur/eye-for-blind-image-to-text -p /path/to/dest

# %%
# !ls "/content/drive/MyDrive/Flickr8k"
# Out:
# captions.txt  Images

# %%
#Import the dataset and read the image into a seperate variable

#import glob

#all_images = glob.glob('/content/drive/My Drive/ImageCaptioning/Images/*.jpg')
#print("The total images present in the dataset: {}".format(len(all_images)))

import glob 
images='/content/drive/MyDrive/Flickr8k/Images'

all_images = glob.glob(images + '/*.jpg',recursive=True)
print("The total images present in the dataset: {}".format(len(all_images)))
# Out:
# The total images present in the dataset: 8167

# %%
#Visualise both the images & text present in the dataset
all_images
# Out:
# ['/content/drive/MyDrive/Flickr8k/Images/386160015_d4b31df68e.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/381239475_044cbffa2b.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/387974450_bcd205daac.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/391020801_aaaae1e42b.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/382151094_c7376cf22b.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/392976422_c8d0514bc3.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/393284934_d38e1cd6fe.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/390360326_26f5936189.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/387078972_514a38dc33.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/385186343_464f5fc186.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/381976882_0063d16d88.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/384577800_fc325af410.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/391723162_3bdeb7ea33.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/392467282_00bb22e201.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/381052465_722e00807b.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/386656845_4e77c3e3da.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/381514859_b40418d9c3.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/390992388_d74daee638.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/390986651_c801db91a0.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/391324644_d23fdf06cb.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/390671130_09fdccd52f.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/380590140_25b9889772.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/390987167_2d5905b459.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/386470686_1ae9242878.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/390992102_67fa31b22f.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/383223174_7165a54c30.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/391106734_d374bc3080.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/384465370_9918873f9a.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/389643437_9a9830a3ba.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/388386075_9ac3a89ada.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/387830531_e89c192b92.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/382701159_f98c1988cd.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/391579205_c8373b5411.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/386655611_1329495f97.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/382090166_be2c2c63e1.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/384465575_31294122c0.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/404890608_33f138aefa.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/405051459_3b3a3ba5b3.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/400562847_e15aba0aac.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/394136487_4fc531b33a.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/397547349_1fd14b95af.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/398413603_166896900f.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/399212516_d68046b277.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/401079494_562454c4d6.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/397815951_3b02090324.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/399679638_d3036da331.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/394161692_2576920777.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/405534893_2d0f3b0147.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/397451339_76a84bd310.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/397982550_cf9f5cdb74.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/403523132_73b9a1a4b3.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/394463341_5311c53783.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/405331006_4e94e07698.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/404216567_75b50b5a36.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/396763804_3b7f1e12a8.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/393987665_91d28f0ed0.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/396360611_941e5849a3.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/400851260_5911898657.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/397725001_e51f7c391c.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/397601572_9587a39291.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/394563330_68b566368c.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/393958545_48c17c66d1.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/395461421_c586b136de.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/404702274_fa8b3fe378.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/393810324_1c33760a95.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/405534993_5158644f98.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/405253184_5f611f3880.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/404850242_3a55a4c874.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/403678611_73978faed7.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/398662202_97e5819b79.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/399246804_b4b5dc70e1.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/397286183_745abbf40d.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/401476986_73918145a3.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/396179143_e1511336e1.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/413231421_43833a11f5.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/415118186_64defc96f3.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/416106657_cab2a107a5.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/413737417_b0a8b445e9.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/410413536_11f1127c46.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/412082368_371df946b3.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/408233586_f2c1be3ce1.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/405961988_fcfe97f31e.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/412101267_7257e6d8c0.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/408573233_1fff966798.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/415793623_6c1225ae27.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/411011549_1298d2b4d2.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/416788726_5b4eb1466e.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/412203580_2c7278909c.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/411175971_0fffd3b8c6.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/406642021_9ec852eccf.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/409327234_7b29eecb4e.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/407678652_1f475acd65.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/405537503_f66ecc5073.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/411863595_d77156687e.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/412056525_191724b058.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/408748500_e8dc8c0c4f.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/414773731_c3f5bf43d5.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/410422753_de506155fa.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/414568315_5adcfc23c0.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/407569668_19b3f8eaf6.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/407008823_bdd7fc6ed5.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/405615014_03be7ef618.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/411216802_aead9e67e3.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/406248253_27b5eba25a.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/415657941_454d370721.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/416650559_cd08d3cd96.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/416960865_048fd3f294.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/408627152_1feaa4b94e.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/406901451_7eafd7568a.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/410453140_5401bf659a.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/405970010_8cebaa77d3.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/410042380_517ccee020.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/427082246_5bf1c3676f.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/424506167_01f365726b.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/421730441_6b2267fd31.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/421322723_3470543368.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/426191845_1e979e9345.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/426920445_d07d1fd0f7.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/416992999_654a99a903.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/41999070_838089137e.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/42637986_135a9786a6.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/425518464_a18b87c563.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/425706089_f138118e12.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/420355149_f2076770df.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/418357172_bdddf71d32.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/424307754_1e2f44d265.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/424416723_19c56cb365.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/426065353_e9a604a01f.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/425088533_a460dc4617.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/423066487_07757b2b49.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/427557693_1108566fd2.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/417577408_eb571658c1.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/422756764_e7eaac76bf.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/421932359_edbf181f44.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/424379231_23f1ade134.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/421808539_57abee6d55.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/418796494_bdb441de42.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/418667611_b9995000f4.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/421706022_1ddb6a7a78.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/421153376_d1d325568f.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/417966898_a04f9b5349.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/421316045_ae7a1eb4bc.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/426805536_d1d5e68c17.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/419116771_642800891d.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/424869823_7aec015d87.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/422763475_0bc814dac6.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/424779662_568f9606d0.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/42637987_866635edf6.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/418616992_22090c6195.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/427167162_2c99779444.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/433855742_c2a6fda763.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/427936315_0b8f7b8d23.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/434938585_fbf913dfb4.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/430803349_a66c91f64e.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/431410325_f4916b5460.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/435739506_2daf7f4887.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/437917001_ae1106f34e.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/432167214_c17fcc1a2d.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/433810429_a4da0eac50.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/436013859_793d870b6f.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/435827376_4384c3005a.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/436393371_822ee70952.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/428408242_b32faf2240.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/428483413_b9370baf72.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/436608339_f1d1298770.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/431282339_0aa60dd78e.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/428485639_a82635d6ee.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/437527058_189f2a7eef.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/434433505_966e50e17d.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/436015762_8d0bae90c3.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/428796930_476a3d6395.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/429205889_ff5a006311.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/429851331_b248ca01cd.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/429174232_ddd4ff5e0b.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/437054333_5c2761b8cd.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/429283612_37f6e7fb7f.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/432496659_f01464d9fb.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/427683329_95d510a087.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/436009777_440c7679a1.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/431018958_84b2beebff.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/432490118_54a9c0e500.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/430964917_022995afb6.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/435054077_3506dbfcf4.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/430173345_86388d8822.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/437404867_209625774d.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/429270993_294ba8e64c.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/432248727_e7b623adbf.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/434792818_56375e203f.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/442220883_ff3d6e507f.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/440190907_bf8b7ba8ef.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/439569646_c917f1bc78.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/445655284_c29e6d7323.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/439492931_a96d590e40.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/446291803_2fd4641b99.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/439916996_1ddb9dc8e7.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/447733067_09cfac3286.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/444881000_bba92e585c.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/439049388_3dcee2d30b.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/442918418_0f29c97fa9.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/445861800_75fc6a8c16.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/445148321_9f2f3ac711.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/446138054_d40c66d5f0.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/440184957_267f3f3a2b.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/444845904_a4531c811a.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/440737340_5af34ca9cf.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/438639005_208bc59b0b.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/44129946_9eeb385d77.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/444057017_f1e0fcaef7.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/447111935_5af98563e3.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/441398149_297146e38d.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/448252603_7d928c900e.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/441212506_fcc321ac28.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/439037721_cdf1fc7358.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/447800028_0242008fa3.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/444481722_690d0cadcf.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/443885436_6e927e6c58.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/441921713_1cafc7d7d2.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/444872454_9f51e07f88.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/446286714_dcec7f339e.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/444803340_fdcaab86f9.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/446514680_ff5ca15ece.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/442594271_2c3dd38483.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/443430496_3fea95a07d.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/444047125_66b249287c.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/441817653_fbdf83060b.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/447722389_4b51b7e13d.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/454691853_cc1e0fa6a1.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/457945610_1a23b9ced0.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/457631171_12b1aee828.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/458735196_176e7df6b3.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/460195978_fc522a4979.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/460478198_83039f2593.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/456299217_b2802efbc2.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/450596617_ed37ec0fe4.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/449352117_63c359c6e7.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/455611732_d65bf3e976.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/460781612_6815c74d37.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/44856031_0d82c2c7d1.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/448590900_db83c42006.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/460350019_af60511a3b.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/460935487_75b2da7854.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/452419961_6d42ab7000.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/451326127_2d95a2e1c2.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/452416075_60b2bb5832.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/453473508_682c0a7189.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/451597318_4f370b1339.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/449287870_f17fb825d7.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/453756106_711c20471a.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/454709143_9c513f095c.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/452363869_cad37e609f.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/459284240_5a4167bf92.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/451081733_40218cec31.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/459814265_d48ba48978.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/448257345_ce149c2ea6.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/458183774_afe65abf67.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/452345346_afe1248586.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/454686980_7517fe0c2e.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/455856615_f6361d9253.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/448916362_17f3f1d0e1.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/458004873_f084c47a88.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/456512643_0aac2fa9ce.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/457875937_982588d918.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/458213442_12c59e61a0.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/448658518_eec0b648a6.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/459778335_857d8ffebf.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/470887781_faae5dae83.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/468871328_72990babd4.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/468608014_09fd20eb9b.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/462288558_b31a8a976f.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/466176275_f40d37851e.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/468930779_8008d90e10.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/464527562_a18f095225.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/466956675_a2fb6bf901.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/463978865_c87c6ca84c.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/464506846_1734302b58.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/468918320_9c275b877f.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/469617651_278e586e46.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/463786229_b54c9a3436.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/470887791_86d5a08a38.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/469969326_4b84073286.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/460973814_5eacd1ced4.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/468102269_135938e209.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/461019788_bc0993dabd.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/470887785_e0b1241d94.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/467960888_6943257534.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/465859490_b077219424.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/468141298_3154d717e1.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/462198798_89e2df0358.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/464251704_b0f0c4c87a.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/461505235_590102a5bf.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/466956209_2ffcea3941.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/470373679_98dceb19e7.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/467858872_f3431df682.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/468911753_cc595f5da0.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/464116251_1ac4bc91f8.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/468310111_d9396abcbd.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/469029994_349e138606.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/469259974_bb03c15c42.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/469021173_aa31c07108.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/470887795_8443ce53d0.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/465994762_1760e83c5d.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/462080147_ca088e6541.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/463875230_f19e83d6df.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/476759700_8911f087f8.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/472661386_723aae880b.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/475980315_b8ecd50094.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/478209058_21e2c37c73.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/478750151_e0adb5030a.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/473220329_819a913bbb.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/47870024_73a4481f7d.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/481054596_cad8c02103.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/472396131_6e97068d93.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/475778645_65b7343c47.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/475313618_bdb2f72be5.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/470903027_489cc507de.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/476760133_c33d2bd83d.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/475317104_1cdc1653b4.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/477254932_56b48d775d.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/478208896_90e7187b64.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/480200554_6155e9dfeb.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/47871819_db55ac4699.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/477768471_d7cd618fdb.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/472860064_a96a228796.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/480505313_2dc686e5db.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/473988700_570422001b.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/472535997_0dbf42b9f3.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/478754346_addb53893c.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/479807465_cf42f39d00.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/479807833_85eed6899c.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/476233374_e1396998ef.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/476740978_45b65ebe0c.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/471402959_0b187560df.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/480607352_65614ab348.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/481732592_b50194cb89.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/475042270_719ebe6c48.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/477204750_d04d111cd4.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/475816542_f5c2736815.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/481632457_7372f18275.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/478592803_f57cc9c461.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/481827288_a688be7913.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/479807115_3a484fb18b.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/488416045_1c6d903fe0.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/486300784_2cc7a770ff.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/482098572_e83153b300.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/485738889_c2a00876a6.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/481887827_f8975dabf1.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/488356951_b3b77ad832.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/488196964_49159f11fd.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/488408004_a1e26d4886.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/488590040_35a3e96c89.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/482353373_03a9d5e8bc.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/486720042_b785e7f88c.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/483136916_16976f4902.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/485566887_57eac33bd1.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/485312202_784508f2a9.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/483841513_e660391880.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/489065557_0eb08889cd.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/484896012_7787d04f41.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/485054073_fef8b80b4b.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/488089932_c3a5fa4140.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/485245061_5a5de43e20.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/482830610_13a0a6c924.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/482088914_e6ea4501e9.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/482882307_7dcb9eee11.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/487487795_54705c406e.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/482907079_22085ada04.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/487071033_27e460a1b9.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/487894806_352d9b5e66.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/485741580_ab523fa657.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/488352274_9a22064cb3.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/489134459_1b3f46fc03.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/482047956_9a29e9cee6.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/483039719_75181b2726.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/487074671_66db20bf47.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/482882719_165722082d.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/485357535_b45ba5b6da.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/488549693_a1f51d8c4a.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/486712504_36be449055.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/486917990_72bd4069af.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/485921585_1974b1577a.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/494921598_af73bda568.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/49553964_cee950f3ba.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/492341908_1ef53be265.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/493621130_152bdd4e91.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/494329594_6e751372a0.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/495054019_3dee8a02f5.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/491964988_414b556228.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/491405109_798222cfd0.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/490390951_87395fcb1c.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/493542985_c85ad29ebe.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/496971341_22782195f0.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/494221578_027f51cdf4.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/495116214_f1df479fb0.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/495341977_b27279f962.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/495055747_a75872762a.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/497122685_a51b29dc46.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/496110746_a93ca191ae.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/495014499_8fd065cfd9.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/494792770_2c5f767ac0.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/489773343_a8aecf7db3.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/490044494_d2d546be8d.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/492493570_c27237a396.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/489865145_65ea6d1c14.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/493507605_48fe8e3739.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/495033548_bd320405d8.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/489551372_b19a6ad0ed.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/491564019_1ca68d16c1.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/494907021_321e82877a.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/496606439_9333831e73.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/493109089_468e105233.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/489372715_ce52da796a.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/496380034_d22aeeedb3.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/496555371_3e1ee0d97d.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/491600485_26c52c8816.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/496129405_b9feeda1ab.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/492802403_ba5246cfea.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/495340319_705f2e63d6.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/502884177_25939ac000.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/506738508_327efdf9c3.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/506367606_7cca2bba9b.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/498748832_941faaaf40.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/503717911_fc43cb3cf9.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/498957941_f0eda42787.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/501684722_0f20c4e704.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/501699433_f8df386cf9.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/497579819_f91b26f7d3.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/501650847_b0beba926c.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/505955292_026f1489f2.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/503090187_8758ab5680.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/503794526_603a7954d3.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/501520507_c86f805ab8.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/504765160_b4b083b293.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/505062117_a70b4e10ab.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/505929313_7668f021ab.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/504385521_6e668691a3.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/500308355_f0c19067c0.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/502671104_b2114246c7.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/500678178_26ce0f4417.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/506412121_67ecc7ec05.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/498404951_527adba7b8.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/498492764_fe276e505a.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/498794783_cc2ac62b47.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/498444334_a680d318a1.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/504904434_889f426c6e.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/506882688_b37d549593.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/506343925_b30a235de6.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/501320769_31eea7b7ea.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/502783522_3656f27014.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/502115726_927dd684d3.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/497791037_93499238d8.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/50030244_02cd4de372.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/506478284_7cf8bdbe36.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/500446858_125702b296.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/506808265_fe84ada926.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/505944126_f9a6ab8944.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/512163695_51a108761d.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/508929192_670910fdd2.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/508261758_78fb8ae067.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/515797344_4ae75cb9b1.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/508432819_3d055f395d.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/514073775_56796be990.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/512026551_ba63ddbd31.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/510531976_90bbee22a2.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/507758961_e63ca126cc.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/510197538_0a11b94460.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/508958120_afe274f726.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/509241560_00e5b20562.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/514222285_aa0c8d05b7.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/514431934_9cf78f05a9.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/512991147_dc48e6839c.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/512634877_d7ad8c8329.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/511844627_0ec78e01e9.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/515702827_be3c6ce857.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/515755283_8f890b3207.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/512550372_438849ce19.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/509200598_171a1ab6c8.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/511749704_3037806cb1.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/509123893_07b8ea82a9.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/512031915_0dd03dcdf9.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/510510783_b2cf5d57bb.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/514990193_2d2422af2c.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/509778093_21236bb64d.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/512045825_1be2083922.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/511282305_dbab4bf4be.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/510791586_3913ade6a7.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/512306469_1392697d32.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/514222303_cb98584536.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/514036362_5f2b9b7314.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/514905846_b54d13946a.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/513269597_c38308feaf.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/513116697_ad0f4dc800.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/512101751_05a6d93e19.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/515335111_c4afd5b903.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/524698457_77ba13840a.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/522700240_d9af45e60d.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/521186251_e97d1f50f8.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/523985664_c866af4850.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/516648762_0cff84ea97.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/524036004_6747cf909b.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/524105255_b346f288be.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/522652105_a89f1cf260.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/516394876_8b9b8021bc.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/516998046_1175674fcd.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/518610439_b64ab21c02.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/524360969_472a7152f0.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/517102724_a0f3069156.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/523692399_d2e261a302.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/522486784_978021d537.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/518251319_40e031e818.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/523327429_af093fc7cf.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/517094985_4b9e926936.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/524031846_28b11bc0e5.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/519228867_2fd25e38d4.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/525538142_7348f0bce7.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/523991446_65dbc5a4a5.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/516725192_c9cdd63878.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/524310507_51220580de.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/518789868_8895ef8792.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/519754987_51861fea85.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/521658170_a837af87e9.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/516214924_c2a4364cb3.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/523249012_a0a25f487e.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/519059913_4906fe4050.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/518144037_9a1754b2a6.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/525863257_053333e612.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/524282699_71e678a6bd.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/519061891_320061864e.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/519167484_ee03e2a91e.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/516761840_842dabc908.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/522063319_33827f1627.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/525887861_4cc7a1beca.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/520491467_54cbc0a866.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/533979933_a95b03323b.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/534056823_0752303702.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/531197115_2be4d5034b.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/534886684_a6c9f40fa1.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/532457586_bddfc5251d.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/534313000_4ad39c7ee0.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/527968666_1fcddf81ab.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/528498076_43f0ef36b5.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/534669139_1a4f8ab9d5.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/533713001_2d36e93509.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/530661899_94655d7d0e.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/532396029_ce125bda3f.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/528500099_7be78a0ca5.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/533483374_86c5d4c13e.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/532036676_e88b13e0a1.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/531152619_6db02a7ed9.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/531055369_936fd76a63.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/530950375_eea665583f.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/529198549_5cd9fedf3f.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/527946505_a51ade1578.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/527272653_8a5bd818e5.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/526661994_21838fc72c.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/534200447_b0f3ff02be.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/532999240_1409d073be.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/525968880_82623392d1.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/530454257_66d58b49ee.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/533602654_9edc74385d.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/533713007_bf9f3e25b4.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/531261613_f1a045cd75.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/534655560_dc1c335b3f.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/532914728_c5d8d56b0b.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/534875358_6ea30d3091.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/526955751_f519d62b58.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/529101401_ab1f6b1206.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/530888330_a18343e38d.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/527288854_f26127b770.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/532131603_c82d454c8a.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/53043785_c468d6f931.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/537479916_c033897fac.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/539750844_02a07ec524.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/540721368_12ac732c6c.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/536828916_b763b82949.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/539751252_2bd88c456b.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/536537638_f5ee42410b.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/540338917_57069687be.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/539676201_c8f1f04952.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/537628742_146f2c24f8.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/540604040_bec822c144.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/541046380_513e295384.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/537758332_8beb9cf522.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/539761097_5c6c70425b.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/539493423_9d7d1b77fa.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/535249787_0fcaa613a0.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/537390477_7dd3407f96.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/539667015_fd0a3bea07.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/535399240_0714a6e950.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/537230454_1f09199476.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/537225246_dd0e2158a7.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/540873795_ae62ae6f60.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/537359971_6e28f5e66e.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/539493431_744eb1abaa.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/537222436_ab406234ce.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/537559285_29be110134.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/537579448_a7f92cef58.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/539801139_7258ee437f.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/535123126_c06c1ab9bf.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/538825260_a4a8784b75.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/539705321_99406e5820.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/535830521_aa971319fc.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/535309053_ec737abde8.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/539744890_85e63f5854.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/537532165_e4b7c0e61a.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/535529555_583d89b7f2.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/536721406_884ab8fece.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/536495604_b22bbc905a.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/541063419_a5f3672d59.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/557721978_dfde31bc02.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/544122267_e9e0100bc5.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/549887636_0ea5ae4739.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/543007912_23fc735b99.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/542179694_e170e9e465.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/551403320_dfdcf9fc3b.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/548751378_c657401312.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/542648687_adf13c406b.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/542269487_5d77b363eb.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/542317719_ed4dd95dc2.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/543102698_38e7e38bbc.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/543326592_70bd4d8602.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/543291644_64539956e9.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/554774472_b5d165ff69.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/55473406_1d2271c1f2.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/55135290_9bed5c4ca3.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/54723805_bcf7af3f16.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/544257613_d9a1fea3f7.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/543940240_a54a3c7989.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/543603259_ef26d9c72d.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/560278886_df4bd2e212.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/544576742_283b65fa0d.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/557101732_32bbc47c12.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/543363241_74d8246fab.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/543264612_c53cc163b4.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/549520317_af3d5c32eb.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/556568556_bc5124dc8e.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/54501196_a9ac9d66f2.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/551664516_78a5131dc4.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/561179890_af8e31cb2e.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/542405691_0594b1ce72.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/544301311_5e7d69a517.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/559102835_472ff702b5.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/541063517_35044c554a.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/557601144_50b8c40393.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/561179884_8b6b925ef9.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/554526471_a31f8b74ef.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/55470226_52ff517151.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/582788646_dc40748639.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/583174725_6b522b621f.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/575636303_b0b8fd4eee.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/561417861_8e25d0c0e8.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/576920249_df1bdc2068.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/572618443_647483ca82.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/571507143_be346225b7.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/57422853_b5f6366081.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/582899605_d96f9201f1.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/58363928_6f7074608c.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/576093768_e78f91c176.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/583087629_a09334e1fb.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/587604325_af5d6df679.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/565605894_8f0bed0438.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/57417274_d55d34e93e.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/597543181_6a85ef4c17.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/576075451_5e0f6facb3.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/58368365_03ed3e5bdf.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/584484388_0eeb36d03d.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/58363930_0544844edd.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/566384456_97da3c7bd6.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/566794440_f9ec673a2f.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/578274277_652cae32ba.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/562588230_edb2c071c8.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/566794036_60f7acdf35.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/578644583_da3ff18dd1.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/58357057_dea882479e.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/56494233_1824005879.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/574274795_57e0834e7d.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/581419370_30485f3580.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/566446626_9793890f95.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/561940436_64d6fc125d.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/571130875_30051ac02d.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/590445887_4d4fa43923.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/566921157_07c18a41e2.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/566397227_a469e9e415.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/56489627_e1de43de34.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/562928217_21f967a807.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/634891010_9fa189effb.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/611910909_4f8e43e070.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/615916000_5044047d71.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/641893280_36fd6e886a.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/642987597_03b21a1437.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/619169586_0a13ee7c21.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/621000329_84f48948eb.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/617038406_4092ee91dd.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/616177206_0e16c33f6b.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/607339469_af851c4119.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/640506101_ae1145b6d1.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/630476551_2ee7399f77.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/632608471_a70461f123.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/637342973_89f6fac1f7.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/640203018_c0e7175831.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/61209225_8512e1dad5.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/608257195_6ec6f48e37.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/632251903_b36701a5e9.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/613900608_2e49415772.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/652542470_60e858da64.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/618292739_0fdc2ccab0.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/649596742_5ba84ce946.jpg',
# ...
#  '/content/drive/MyDrive/Flickr8k/Images/70995350_75d0698839.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/753578547_912d2b4048.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/746787916_ceb103069f.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/710878348_323082babd.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/752052256_243d111bf0.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/745880539_cd3f948837.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/754852108_72f80d421f.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/757046028_ff5999f91b.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/742073622_1206be8f7f.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/756521713_5d3da56a54.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/72964268_d532bb8ec7.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/757133580_ba974ef649.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/747242766_afdc9cb2ba.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/745966757_6d16dfad8f.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/720208977_f44c2bba5b.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/751109943_2a7f8e117f.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/724702877_f2a938766b.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/735787579_617b047319.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/732468337_a37075225e.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/751737218_b89839a311.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/717673249_ac998cfbe6.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/745563422_f4fa7d9157.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/719837187_3e7bf1d472.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/733964952_69f011a6c4.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/749840385_e004bf3b7c.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/72218201_e0e9c7d65b.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/750196276_c3258c6f1b.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/753285176_f21a2b984d.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/756909515_a416161656.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/755326139_ee344ece7b.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/756004341_1a816df714.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/716597900_b72c58362c.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/733172023_5810350af6.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/778885185_3f6905370b.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/788126442_086334f0cf.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/763577068_4b96ed768b.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/771048251_602e5e8f45.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/774009278_8e75b7d498.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/766099402_cdda6964f0.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/799486353_f665d7b0f0.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/802594049_289e3c8420.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/782401952_5bc5d3413a.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/759015118_4bd3617e60.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/783353797_fdf91bdf4c.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/765929807_de381cc764.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/783994497_4f6885454d.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/760138567_762d9022d4.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/792362827_5ab5281b99.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/791338571_7f38510bf7.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/799431781_65dc312afc.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/804087017_330bcc8c56.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/765298136_7805fbb079.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/798343627_7492fe0c12.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/765091078_a8a11c6f9e.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/762947607_2001ee4c72.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/775664534_3f6de7d413.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/758921886_55a351dd67.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/772212710_f5fc22ed35.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/757332692_6866ae545c.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/760180310_3c6bd4fd1f.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/766346887_a9a9d0637a.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/771366843_a66304161b.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/781118358_19087c9ec0.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/769260947_02bc973d76.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/782017931_75d92bb7a4.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/772403830_08b72c7da9.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/781387473_208ba152b3.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/801607443_f15956d1ce.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/799199774_142b1c3bb2.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/766061382_6c7ff514c4.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/795081510_53fd17d101.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/78984436_ad96eaa802.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/824923476_d85edce294.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/824123145_59243e504e.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/838074897_9d6270b3cd.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/836828001_af98d16256.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/843616798_5ab0ecb525.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/820169182_f5e78d7d19.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/856985136_649c0a3881.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/836768303_d748df5546.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/854333409_38bc1da9dc.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/811663364_4b350a62ce.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/812196663_0c969970b5.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/857914283_270d7d1c87.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/822836318_21544f0f78.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/832128857_1390386ea6.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/818340833_7b963c0ee3.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/823697339_aadbeef495.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/837893113_81854e94e3.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/837919879_94e3dacd83.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/811662356_f9a632b63c.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/847782643_57248bbdab.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/808245064_8a7971fc5b.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/823675317_b5fbdb17b3.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/848293676_98e73c52c1.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/852469220_bc0fee3623.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/846085364_fc9d23df46.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/848180689_d67a1361ce.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/825918657_d92f1761f4.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/835415474_7b7f2a9768.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/827941668_2e4ac6cb39.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/816084977_21c1811c9a.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/805682444_90ed9e1ef3.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/839295615_bb9baf2f95.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/860928274_744d14f198.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/84713990_d3f3cef78b.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/842961005_692737888e.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/842960985_91daf0d6ec.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/824782868_a8f532f3a6.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/859620561_de417cac1e.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/862156271_3eacea90a8.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/892340814_bdd61e10a4.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/895502702_5170ada2ee.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/888517718_3d5b4b7b43.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/872512911_ca383b40e4.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/883040210_3c4a10f030.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/86412576_c53392ef80.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/86542183_5e312ae4d4.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/862177617_c2c0581075.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/871290646_307cddd4e7.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/905355838_3a43fdfd4e.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/861661418_8a37024ace.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/871290666_4877e128c0.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/90011335_cfdf9674c2.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/870710405_51e507b31a.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/861795382_5145ad433d.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/887108308_2da97f15ef.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/872135364_8c1e47d163.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/866841633_05d273b96d.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/888425986_e4b6c12324.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/862054277_34b5a6f401.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/872622575_ba1d3632cc.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/900144365_03cd1899e3.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/909191414_1cf5d85821.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/894928353_002a3d5f06.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/864290968_eccb46d5ab.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/873633312_a756d8b381.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/861608773_bdafd5c996.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/862187579_9faf4a51e0.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/899810584_61e1578d3f.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/881725588_efabbcd96a.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/878758390_dd2cdc42f6.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/880220939_0ef1c37f1f.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/897621891_efb1e00d1d.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/890734502_a5ae67beac.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/875731481_a5a0a09934.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/874665322_9ad05c4065.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/897406883_f09f673d94.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/940973925_a2e6d7951c (1).jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/95151149_5ca6747df6.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/946051430_8db7e4ce09.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/933118213_b35b0b62a7 (1).jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/942399470_6132d3e5d2 (1).jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/942399470_6132d3e5d2.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/95728664_06c43b90f1.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/947664583_7c63172366.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/95728660_d47de66544.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/925491651_57df3a5b36.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/938162709_21443d352f (1).jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/956164675_9ee084364e.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/944374205_fd3e69bfca.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/940973925_a2e6d7951c.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/938162709_21443d352f.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/957230475_48f4285ffe.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/948196883_e190a483b1.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/94232465_a135df2711 (1).jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/929679367_ff8c7df2ee.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/911527312_f81ee36b97.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/953941506_5082c9160c.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/911795495_342bb15b97.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/918886676_3323fb2a01.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/930748509_8ca5cf5c24.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/917574521_74fab68514.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/952171414_2db16f846f.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/93922153_8d831f7f01 (1).jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/95734035_84732a92c1.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/934375844_dd149fed18 (1).jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/909808296_23c427022d.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/944788251_a0bcd4b960 (1).jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/927420680_6cba7c040a.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/950273886_88c324e663.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/954987350_a0c608b467.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/944788251_a0bcd4b960.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/934375844_dd149fed18.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/950411653_20d0335946.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/937559727_ae2613cee5 (1).jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/937559727_ae2613cee5.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/947969010_f1ea572e89.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/95734036_bef6d1a871.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/933118213_b35b0b62a7.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/930126921_1b94605bdc.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/923550133_ac9d7a2932.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/945509052_740bb19bc3.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/989754491_7e53fb4586.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/990890291_afc72be141.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/96978713_775d66a18d.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/98377566_e4674d1ebd.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/97731718_eb7ba71fd3.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/963730324_0638534227.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/974924582_10bed89b8d.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/987907964_5a06a63609.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/95734038_2ab5783da7.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/964197865_0133acaeb4.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/970641406_9a20ee636a.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/99171998_7cc800ceef.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/99679241_adc853a5c0.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/967719295_3257695095.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/961189263_0990f3bcb5.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/968081289_cdba83ce2e.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/976392326_082dafc3c5.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/96973080_783e375945.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/96399948_b86c61bfe6.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/96420612_feb18fc6c6.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/975131015_9acd25db9c.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/977856234_0d9caee7b2.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/972381743_5677b420ab.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/973827791_467d83986e.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/97577988_65e2eae14a.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/979383193_0a542a059d.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/978580450_e862715aba.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/958326692_6210150354.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/989851184_9ef368e520.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/961611340_251081fcb8.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/97105139_fae46fe8ef.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/965444691_fe7e85bf0e.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/97406261_5eea044056.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/985067019_705fe4a4cc.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/957682378_46c3b07bcd.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/95783195_e1ba3f57ca.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/979201222_75b6456d34.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/96985174_31d4c6f06d.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/997722733_0cb5439472.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/997338199_7343367d7f.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/3524612244_64f00afec5.jpg',
#  '/content/drive/MyDrive/Flickr8k/Images/3525453732_f74a38f111.jpg',
#  ...]

# %%
from IPython.display import Image

#image names taken randomly from image folder to check.

#a = Image(filename='Flickr8K/Images/225909073_25c3c33a29.jpg')
#b = Image(filename='Flickr8K/Images/256085101_2c2617c5d0.jpg')

#display(a,b)

import random
from skimage import io
Display_Images= random.shuffle(all_images)

imgs=all_images[:5]
figure, axes = plt.subplots(1,5)
figure.set_figwidth(15)
   
for ax,image in zip(axes, imgs):
    ax.imshow(io.imread(image), cmap=None)

# %%
#Import the dataset and read the text file into a seperate variable

text_file = "Flickr8K/captions.txt"

def load_doc(filename):
    file = open(filename, 'r',encoding="latin-1")
    text = file.read()
    #print(text)
    file.close()
    return text

doc = load_doc(text_file)
print(doc[:300])
# Out:
# image,caption
# 1000268201_693b08cb0e.jpg,A child in a pink dress is climbing up a set of stairs in an entry way .
# 1000268201_693b08cb0e.jpg,A girl going into a wooden building .
# 1000268201_693b08cb0e.jpg,A little girl climbing into a wooden playhouse .
# 1000268201_693b08cb0e.jpg,A little girl climbing

# %% [markdown]
# Create a dataframe which summarizes the image, path & captions as a dataframe
#
# Each image id has 5 captions associated with it therefore the total dataset should have 40455 samples.

# %%
img = 'Flickr8k/Images/'

def get_imgsid_captions(text):
    ids=[]
    vals=[]
    ids_paths=[]
    text=text.splitlines()[1:]
    for line in text:
        co_idx=line.index(",")
        im_id,im_cap=line[:co_idx],line[co_idx+1:]
        ids.append(im_id)
        vals.append(im_cap)
        ids_paths.append(img+im_id)
    return ids,vals,ids_paths

# %%
#all_img_id= #store all the image id here
#all_img_vector= #store all the image path here
#annotations= #store all the captions here
all_img_id,annotations,all_img_vector= get_imgsid_captions(doc)#store all the image id here

capdf = pd.DataFrame(list(zip(all_img_id, all_img_vector,annotations)),columns =['ID','Path', 'Captions']) 
    
capdf
# Out:
#                               ID                                       Path  \
# 0      1000268201_693b08cb0e.jpg  Flickr8k/Images/1000268201_693b08cb0e.jpg
# 1      1000268201_693b08cb0e.jpg  Flickr8k/Images/1000268201_693b08cb0e.jpg
# 2      1000268201_693b08cb0e.jpg  Flickr8k/Images/1000268201_693b08cb0e.jpg
# 3      1000268201_693b08cb0e.jpg  Flickr8k/Images/1000268201_693b08cb0e.jpg
# 4      1000268201_693b08cb0e.jpg  Flickr8k/Images/1000268201_693b08cb0e.jpg
# ...                          ...                                        ...
# 40450   997722733_0cb5439472.jpg   Flickr8k/Images/997722733_0cb5439472.jpg
# 40451   997722733_0cb5439472.jpg   Flickr8k/Images/997722733_0cb5439472.jpg
# 40452   997722733_0cb5439472.jpg   Flickr8k/Images/997722733_0cb5439472.jpg
# 40453   997722733_0cb5439472.jpg   Flickr8k/Images/997722733_0cb5439472.jpg
# 40454   997722733_0cb5439472.jpg   Flickr8k/Images/997722733_0cb5439472.jpg
#
#                                                 Captions
# 0      A child in a pink dress is climbing up a set o...
# 1                  A girl going into a wooden building .
# 2       A little girl climbing into a wooden playhouse .
# 3      A little girl climbing the stairs to her playh...
# 4      A little girl in a pink dress going into a woo...
# ...                                                  ...
# 40450           A man in a pink shirt climbs a rock face
# 40451           A man is rock climbing high in the air .
# 40452  A person in a red shirt climbing up a rock fac...
# 40453                    A rock climber in a red shirt .
# 40454  A rock climber practices on a rock climbing wa...
#
# [40455 rows x 3 columns]

# %%
capdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40455 entries, 0 to 40454
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        40455 non-null  object
#  1   Path      40455 non-null  object
#  2   Captions  40455 non-null  object
# dtypes: object(3)
# memory usage: 948.3+ KB

# %%
print(capdf['Captions'])
# Out:
# 0        A child in a pink dress is climbing up a set o...
# 1                    A girl going into a wooden building .
# 2         A little girl climbing into a wooden playhouse .
# 3        A little girl climbing the stairs to her playh...
# 4        A little girl in a pink dress going into a woo...
#                                ...
# 40450             A man in a pink shirt climbs a rock face
# 40451             A man is rock climbing high in the air .
# 40452    A person in a red shirt climbing up a rock fac...
# 40453                      A rock climber in a red shirt .
# 40454    A rock climber practices on a rock climbing wa...
# Name: Captions, Length: 40455, dtype: object

# %%
def create_vocabulary(data):
  vocab = []
  for captions in data.Captions.values:
    vocab.extend(captions.split())
  print("Vocabulary Size : {}".format(len(set(vocab))))
  return vocab

# %%
#Create the vocabulary & the counter for the captions
from collections import Counter

vocabulary = create_vocabulary(capdf)#write your code here

val_count=Counter(vocabulary)
val_count
# Out:
# Vocabulary Size : 9862
# Counter({'A': 21481,
#          'child': 1477,
#          'in': 18961,
#          'a': 40271,
#          'pink': 734,
#          'dress': 347,
#          'is': 9345,
#          'climbing': 502,
#          'up': 1260,
#          'set': 108,
#          'of': 6712,
#          'stairs': 109,
#          'an': 1944,
#          'entry': 1,
#          'way': 50,
#          '.': 34212,
#          'girl': 3217,
#          'going': 149,
#          'into': 1074,
#          'wooden': 284,
#          'building': 509,
#          'little': 1625,
#          'playhouse': 6,
#          'the': 15328,
#          'to': 3173,
#          'her': 1178,
#          'cabin': 4,
#          'black': 3696,
#          'dog': 7982,
#          'and': 8850,
#          'spotted': 37,
#          'are': 3503,
#          'fighting': 132,
#          'tri-colored': 14,
#          'playing': 2008,
#          'with': 7760,
#          'each': 430,
#          'other': 771,
#          'on': 10729,
#          'road': 388,
#          'white': 3875,
#          'brown': 2475,
#          'spots': 29,
#          'staring': 57,
#          'at': 2904,
#          'street': 936,
#          'Two': 3962,
#          'dogs': 2082,
#          'different': 45,
#          'breeds': 5,
#          'looking': 738,
#          'pavement': 48,
#          'moving': 41,
#          'toward': 146,
#          'covered': 306,
#          'paint': 61,
#          'sits': 577,
#          'front': 1386,
#          'painted': 63,
#          'rainbow': 22,
#          'hands': 244,
#          'bowl': 30,
#          'sitting': 1368,
#          'large': 1191,
#          'small': 1207,
#          'grass': 1621,
#          'plays': 526,
#          'fingerpaints': 3,
#          'canvas': 6,
#          'it': 398,
#          'There': 226,
#          'pigtails': 14,
#          'painting': 42,
#          'Young': 176,
#          'outside': 790,
#          'man': 6828,
#          'lays': 56,
#          'bench': 375,
#          'while': 1957,
#          'his': 2357,
#          'by': 1248,
#          'him': 402,
#          'which': 51,
#          'also': 20,
#          'tied': 15,
#          'sleeping': 60,
#          'next': 749,
#          'shirtless': 97,
#          'lies': 43,
#          'park': 503,
#          'laying': 188,
#          'holding': 1324,
#          'leash': 131,
#          'ground': 355,
#          'orange': 732,
#          'hat': 679,
#          'starring': 8,
#          'something': 346,
#          'wears': 115,
#          'glasses': 206,
#          'gauges': 2,
#          'wearing': 3061,
#          'Blitz': 1,
#          'beer': 45,
#          'can': 39,
#          'crocheted': 1,
#          'The': 2920,
#          'pierced': 6,
#          'ears': 69,
#          'rope': 249,
#          'net': 58,
#          'red': 2660,
#          'roping': 2,
#          'climbs': 200,
#          'bridge': 139,
#          'grips': 2,
#          'onto': 211,
#          'ropes': 38,
#          'playground': 201,
#          'running': 2072,
#          'grassy': 473,
#          'garden': 54,
#          'surrounded': 178,
#          'fence': 340,
#          'through': 2031,
#          'Boston': 9,
#          'terrier': 23,
#          'Terrier': 8,
#          'lush': 8,
#          'green': 1218,
#          'runs': 925,
#          'near': 1022,
#          '"A': 1186,
#          'shakes': 37,
#          'its': 925,
#          'head': 374,
#          'shore': 170,
#          ',': 3210,
#          'ball': 1778,
#          '."': 2365,
#          'edge': 170,
#          'beach': 1044,
#          '"Dog': 8,
#          'feet': 87,
#          'stands': 869,
#          'shaking': 71,
#          'off': 744,
#          'water"': 4,
#          'White': 60,
#          'water': 2774,
#          'standing': 1786,
#          'turned': 20,
#          'one': 1007,
#          'side': 303,
#          'boy': 3442,
#          'smiles': 192,
#          'stony': 3,
#          'wall': 555,
#          'city': 317,
#          'overalls': 24,
#          'working': 23,
#          'stone': 127,
#          'young': 2431,
#          'aross': 1,
#          'walking': 1165,
#          'paved': 43,
#          'metal': 113,
#          'pole': 155,
#          'behind': 631,
#          'Smiling': 13,
#          'shirt': 1803,
#          'blue': 2257,
#          'jeans': 224,
#          'rock': 750,
#          'leaps': 204,
#          'over': 1414,
#          'log': 55,
#          'grey': 239,
#          'leaping': 137,
#          'fallen': 70,
#          'tree': 416,
#          'mottled': 2,
#          'collar': 198,
#          'jumping': 1469,
#          'jumped': 33,
#          'stump': 27,
#          'snow': 1481,
#          'field': 1276,
#          'surface': 65,
#          'displaying': 5,
#          'pictures': 66,
#          'skier': 173,
#          'skis': 81,
#          'past': 148,
#          'another': 953,
#          'paintings': 5,
#          'person': 1414,
#          'framed': 7,
#          'looks': 511,
#          'trees': 260,
#          'Man': 410,
#          'artwork': 4,
#          'for': 949,
#          'sale': 7,
#          'collage': 2,
#          'cliff': 195,
#          'group': 1172,
#          'people': 2442,
#          'belays': 1,
#          'Seven': 12,
#          'climbers': 27,
#          'ascending': 8,
#          'face': 482,
#          'whilst': 152,
#          'Several': 188,
#          'row': 33,
#          'watches': 275,
#          'holds': 471,
#          'line': 147,
#          'chases': 99,
#          'from': 920,
#          'sprinkler': 53,
#          'lawn': 117,
#          'hose': 45,
#          'Large': 42,
#          'away': 169,
#          'prepares': 50,
#          'catch': 368,
#          'thrown': 45,
#          'object': 155,
#          'nearby': 153,
#          'cars': 63,
#          'about': 151,
#          'yellow': 1207,
#          'mouth': 986,
#          'toy': 580,
#          'ready': 125,
#          'flying': 173,
#          'air': 1057,
#          'after': 184,
#          'get': 107,
#          'jumps': 978,
#          'towards': 247,
#          'trying': 163,
#          'midair': 210,
#          'woman': 3227,
#          'waters': 29,
#          'big': 272,
#          'lake': 332,
#          'lone': 80,
#          'duck': 36,
#          'swimming': 446,
#          'several': 113,
#          'around': 647,
#          'watching': 250,
#          'waves': 141,
#          'hand': 342,
#          '"Two': 403,
#          'facing': 55,
#          'skyline': 15,
#          'couple': 239,
#          'infant': 14,
#          'being': 338,
#          'held': 66,
#          'male': 111,
#          'pond': 96,
#          'stroller': 28,
#          'sit': 360,
#          'baby': 403,
#          'their': 693,
#          'newborn': 8,
#          'under': 246,
#          'care': 3,
#          'along': 527,
#          'body': 190,
#          'Couple': 8,
#          'outdoors': 174,
#          'surf': 78,
#          'lab': 22,
#          'tags': 7,
#          'frolicks': 2,
#          'splashes': 71,
#          'This': 96,
#          'splashing': 129,
#          'drilling': 5,
#          'hole': 37,
#          'ice': 220,
#          'frozen': 26,
#          'men': 1035,
#          'fishing': 106,
#          'play': 746,
#          'making': 154,
#          'turn': 70,
#          'soft': 13,
#          'sand': 465,
#          'together': 413,
#          'tan': 385,
#          'sandy': 110,
#          'uses': 27,
#          'picks': 12,
#          'crampons': 1,
#          'scale': 1,
#          'climber': 121,
#          'jacket': 678,
#          'pants': 259,
#          'scaling': 20,
#          'An': 455,
#          'waterfall': 85,
#          'two': 1262,
#          'Climber': 3,
#          'carries': 128,
#          'as': 865,
#          'he': 205,
#          'walks': 552,
#          'carrying': 434,
#          'has': 562,
#          'item': 20,
#          'wet': 169,
#          'kayak': 88,
#          'life': 86,
#          'jackets': 68,
#          'rowing': 35,
#          'canoe': 72,
#          'gentle': 1,
#          'ride': 253,
#          'courtyard': 28,
#          'catching': 109,
#          'Black': 129,
#          'snaps': 1,
#          'lunges': 6,
#          'Chocolate': 2,
#          'Lab': 2,
#          'too': 8,
#          'late': 3,
#          'captures': 1,
#          'driveway': 15,
#          'stick': 467,
#          'kneeling': 34,
#          'goalie': 43,
#          'hockey': 182,
#          'guarding': 9,
#          'goal': 82,
#          'kid': 171,
#          'rink': 30,
#          'right': 93,
#          '"Hockey': 1,
#          'crouches': 30,
#          'modern': 5,
#          'art': 39,
#          'structure': 77,
#          'glass': 61,
#          'reads': 46,
#          'newspaper': 38,
#          'sculpture': 22,
#          'office': 12,
#          'statue': 63,
#          'backpack': 158,
#          'buildings': 71,
#          'reading': 96,
#          'tent': 82,
#          'enter': 8,
#          'setting': 81,
#          'hut': 12,
#          'iced': 3,
#          'tarp': 8,
#          'snowy': 420,
#          'three': 298,
#          'Three': 968,
#          'hill': 444,
#          'sky': 146,
#          'them': 260,
#          'stand': 518,
#          'kneels': 26,
#          'skyscraper': 6,
#          'very': 162,
#          'tall': 144,
#          'Behind': 1,
#          'distance': 108,
#          'camera': 687,
#          'bites': 31,
#          'hard': 16,
#          'treat': 16,
#          'biting': 83,
#          'baked': 2,
#          'good': 7,
#          'putting': 35,
#          'both': 81,
#          'eats': 52,
#          'food': 92,
#          'table': 258,
#          'eating': 144,
#          'pizza': 4,
#          'tin': 1,
#          'dish': 11,
#          'People': 414,
#          'mountainside': 26,
#          'check': 6,
#          'out': 757,
#          'view': 80,
#          'hilltop': 2,
#          'overlooking': 104,
#          'valley': 23,
#          'hang': 30,
#          'top': 485,
#          'overlook': 6,
#          'rest': 24,
#          'ledge': 77,
#          'above': 226,
#          'moutains': 1,
#          'down': 1823,
#          'many': 89,
#          'inflatable': 73,
#          'boats': 39,
#          'kayakers': 8,
#          'railing': 112,
#          'rafts': 6,
#          'below': 55,
#          'crowd': 519,
#          'jersey': 114,
#          'pose': 216,
#          'some': 547,
#          'multiracial': 1,
#          'posing': 291,
#          'picture': 416,
#          '"Asian': 4,
#          'blond': 169,
#          'background': 592,
#          'Guy': 15,
#          'striped': 217,
#          'guy': 195,
#          'takeout': 1,
#          'television': 9,
#          'floor': 153,
#          'fast': 51,
#          'meal': 13,
#          'Someone': 86,
#          'TV': 8,
#          'teens': 5,
#          'Crowd': 11,
#          'rail': 102,
#          'crowded': 76,
#          'takes': 169,
#          'jump': 401,
#          'skateboard': 431,
#          'performing': 196,
#          'trick': 384,
#          'leans': 57,
#          'skateboarder': 290,
#          'doing': 434,
#          'board': 139,
#          'platform': 48,
#          'skateboarders': 9,
#          'paddling': 48,
#          'river': 235,
#          'seen': 40,
#          'kayaking': 29,
#          'paddles': 34,
#          'boat': 274,
#          'paddle': 40,
#          'shallow': 130,
#          'girls': 807,
#          'ocean': 460,
#          'four': 132,
#          'children': 1005,
#          'pajamas': 18,
#          'have': 74,
#          'pillow': 15,
#          'fight': 77,
#          'kids': 292,
#          'pillow-fight': 1,
#          'bed': 156,
#          'Children': 143,
#          'having': 48,
#          'Four': 332,
#          'constructions': 1,
#          'workers': 17,
#          'beam': 20,
#          'taking': 204,
#          'break': 33,
#          'construction': 31,
#          'I-beam': 1,
#          'take': 80,
#          'seat': 50,
#          'steel': 4,
#          'boys': 634,
#          'puddle': 93,
#          'balloon': 44,
#          'mud': 114,
#          'sunny': 66,
#          'day': 136,
#          'appears': 36,
#          'wait': 43,
#          'hailing': 1,
#          'taxi': 4,
#          'signaling': 1,
#          'traffic': 47,
#          'blonde': 186,
#          'hair': 413,
#          'tube': 61,
#          'waving': 52,
#          'arm': 148,
#          'oncoming': 2,
#          'brochure': 2,
#          'train': 108,
#          'rides': 458,
#          'magizine': 1,
#          'book': 77,
#          'pamphlet': 1,
#          'Child': 58,
#          'rocky': 244,
#          'run': 366,
#          'across': 476,
#          'stones': 9,
#          'area': 398,
#          'descends': 11,
#          'end': 52,
#          'high': 282,
#          'diving': 73,
#          'pool': 690,
#          'dive': 11,
#          'window': 136,
#          'overshirt': 1,
#          'tank': 76,
#          'chrome': 1,
#          'door': 61,
#          'puts': 34,
#          'elevator': 7,
#          'light-colored': 5,
#          'Light': 5,
#          'swim': 97,
#          'shorts': 376,
#          'trunks': 95,
#          'arms': 247,
#          'outstretched': 38,
#          'hiker': 75,
#          'bluff': 5,
#          'mountains': 204,
#          'ski': 95,
#          "'s": 400,
#          'landscape': 45,
#          'snow-covered': 49,
#          'mountain': 543,
#          'beautiful': 48,
#          'pauses': 10,
#          'mountaintop': 25,
#          'attempting': 57,
#          'purple': 312,
#          'low': 66,
#          'cut': 27,
#          'yard': 201,
#          'Frisbee': 337,
#          'parking': 72,
#          'lot': 108,
#          'middle': 153,
#          'during': 169,
#          'heavy': 25,
#          'mat': 22,
#          'between': 125,
#          'SUV': 14,
#          'pickup': 4,
#          'open': 190,
#          'busy': 97,
#          'terrain': 34,
#          'woolly': 1,
#          'Doberman': 6,
#          'One': 193,
#          'chasing': 184,
#          'catches': 123,
#          'tennis': 424,
#          ',"': 22,
#          'multicolor': 11,
#          'balloons': 28,
#          'night': 158,
#          'hot': 27,
#          'lit': 43,
#          'lined': 36,
#          'nighttime': 12,
#          'helmet': 358,
#          'bike': 859,
#          'miniature': 5,
#          'dirt': 581,
#          'bicycle': 414,
#          'race': 372,
#          'pedals': 3,
#          'quickly': 30,
#          'BMX': 37,
#          'eight': 9,
#          'gathered': 68,
#          'dark': 242,
#          'porch': 24,
#          'darkened': 10,
#          'room': 132,
#          'throwing': 109,
#          'cleans': 2,
#          'bubbles': 89,
#          'suds': 4,
#          'wiped': 2,
#          'clean': 7,
#          'foam': 20,
#          'ramp': 319,
#          'soapy': 1,
#          'getting': 124,
#          'cleaned': 1,
#          'slides': 92,
#          'slide': 300,
#          'wading': 55,
#          'toys': 49,
#          'floating': 38,
#          'backyard': 66,
#          'sliding': 123,
#          'colorful': 217,
#          'tubes': 2,
#          'falling': 80,
#          'colored': 170,
#          'wetsuit': 81,
#          'toddler': 164,
#          'waiting': 118,
#          'come': 11,
#          'so': 16,
#          '"While': 11,
#          'droplets': 7,
#          'fly': 37,
#          'throws': 67,
#          'sticks': 62,
#          'tongue': 111,
#          'Another': 2,
#          'make': 58,
#          'faces': 74,
#          'smiling': 448,
#          'sticking': 53,
#          'look': 257,
#          'silly': 17,
#          'horse': 229,
#          'sweatshirt': 78,
#          'fire': 109,
#          'barrel': 22,
#          'lead': 17,
#          'horses': 89,
#          'contained': 1,
#          'bulldog': 9,
#          'sheep': 55,
#          'boxer': 18,
#          'pushing': 64,
#          'anouther': 1,
#          'skinny': 18,
#          'smaller': 67,
#          'int': 6,
#          'various': 15,
#          'sizes': 4,
#          'lady': 207,
#          'no': 84,
#          'dock': 93,
#          'deck': 39,
#          'closeup': 50,
#          'that': 396,
#          'paws': 30,
#          'lying': 99,
#          'resting': 44,
#          'tiled': 9,
#          'eyes': 92,
#          'rests': 23,
#          'patio': 21,
#          'bricks': 5,
#          'artificial': 10,
#          'safety': 32,
#          'harness': 82,
#          'indoor': 43,
#          '"The': 169,
#          'rocks': 255,
#          'Woman': 158,
#          'ring': 68,
#          'jumphouse': 1,
#          'teenage': 71,
#          'seating': 7,
#          'inflated': 5,
#          'family': 79,
#          'tractor': 9,
#          'Polaris': 3,
#          'vehicle': 79,
#          'played': 19,
#          'wheeler': 12,
#          'riding': 906,
#          'ATV': 39,
#          'costume': 131,
#          'left': 89,
#          'sequined': 4,
#          'feather': 12,
#          'sidewalk': 375,
#          'salmon': 2,
#          'bikini': 66,
#          ';': 32,
#          'outfit': 159,
#          'drinking': 100,
#          'pop': 7,
#          'approached': 2,
#          'flamboyant': 3,
#          'dressed': 563,
#          'feathered': 8,
#          'headress': 1,
#          'Skiiers': 9,
#          'forest': 160,
#          'skiing': 112,
#          'wooded': 101,
#          'cross-country': 18,
#          'skiers': 31,
#          'woodland': 21,
#          'trail': 146,
#          'woods': 210,
#          'hikers': 33,
#          'pathway': 12,
#          'light': 157,
#          'path': 324,
#          'happily': 26,
#          'Energetic': 1,
#          'mother': 40,
#          'boardwalk': 24,
#          'sea': 30,
#          'Some': 76,
#          'pier': 33,
#          'evening': 9,
#          'pony': 12,
#          'wintertime': 2,
#          'atop': 37,
#          'draft': 3,
#          'n': 2,
#          'daft': 1,
#          'pull': 32,
#          'cart': 85,
#          'golden': 101,
#          'sleigh': 4,
#          'driven': 10,
#          'coat': 268,
#          'pulling': 110,
#          'carriage': 19,
#          'sled': 113,
#          'steered': 2,
#          'sheer': 16,
#          'using': 64,
#          'flat': 14,
#          'rappels': 2,
#          'steep': 62,
#          'incline': 11,
#          'vest': 98,
#          'inside': 172,
#          'dome': 3,
#          'Shaft': 1,
#          'cave': 21,
#          'shows': 32,
#          'spelunkers': 1,
#          'Spelunkers': 1,
#          'cavern': 1,
#          'bathed': 1,
#          'sunlight': 11,
#          'backpackers': 2,
#          'lay': 20,
#          'dry': 79,
#          'camp': 6,
#          'gear': 115,
#          'chalk': 17,
#          'portrait': 6,
#          'stream': 111,
#          'drawing': 13,
#          'barn-like': 1,
#          'elaborate': 11,
#          'illustration': 2,
#          'deep': 82,
#          'pile': 76,
#          'fountain': 181,
#          'fountains': 14,
#          'sprayed': 25,
#          'Corgi': 2,
#          'tunnel': 67,
#          'course': 135,
#          'Dog': 144,
#          'obstacle': 125,
#          'obedience': 3,
#          'swimsuit': 61,
#          'Little': 129,
#          'handrail': 33,
#          'bathing': 119,
#          'suit': 244,
#          'spray': 36,
#          'soaked': 12,
#          'jet': 22,
#          'shower': 20,
#          'gets': 107,
#          'underwater': 53,
#          'red-headed': 4,
#          'swims': 104,
#          'gun': 41,
#          'foot': 44,
#          'aims': 5,
#          'fireplace': 11,
#          'new': 7,
#          'light-up': 2,
#          'Boy': 119,
#          'pointed': 13,
#          'alone': 35,
#          'jagged': 7,
#          'snowmobile': 13,
#          'mid': 8,
#          'snowmobiler': 1,
#          'flies': 104,
#          'rider': 183,
#          'or': 87,
#          'machine': 31,
#          'pine': 23,
#          'Rider': 2,
#          'rural': 45,
#          'snowmobiles': 4,
#          'helmets': 39,
#          'goggles': 73,
#          'snowmobiling': 2,
#          'helmeted': 14,
#          'drive': 16,
#          'ATVs': 3,
#          'heads': 49,
#          'wheel': 60,
#          'wheelers': 3,
#          'empty': 49,
#          'all': 137,
#          '!': 9,
#          'gin': 1,
#          'four-wheeler': 5,
#          'airborne': 73,
#          'quad': 6,
#          'harvested': 2,
#          'cornfield': 1,
#          's': 2,
#          'happy': 20,
#          'OD': 1,
#          'playfully': 32,
#          'soccer': 570,
#          'tucked': 1,
#          't-shirt': 145,
#          'Small': 64,
#          'artist': 14,
#          'paints': 12,
#          'clouds': 32,
#          'braids': 6,
#          'colors': 22,
#          'paper': 79,
#          'cyclist': 65,
#          'curved': 4,
#          'aerodynamic': 2,
#          'sharp': 20,
#          'curve': 24,
#          'pedaling': 3,
#          '"Man': 26,
#          'cows': 12,
#          'graze': 2,
#          'biker': 162,
#          'fetch': 31,
#          'pounces': 8,
#          'cine': 1,
#          'old': 161,
#          'fashioned': 6,
#          'video': 39,
#          'steadies': 2,
#          'aim': 4,
#          'Girl': 103,
#          'rosy': 1,
#          'cheeks': 6,
#          'lips': 17,
#          'Border': 2,
#          'Collie': 7,
#          'audience': 38,
#          'dug': 3,
#          'watch': 239,
#          'agile': 1,
#          'onlookers': 48,
#          'closely': 5,
#          'smooth': 6,
#          'stacking': 1,
#          'Toddler': 3,
#          'against': 201,
#          'backdrop': 9,
#          'shoes': 91,
#          'rappeling': 1,
#          'headlamp': 2,
#          'attached': 53,
#          'snakeskin': 1,
#          'Person': 122,
#          'sprays': 11,
#          'frog': 2,
#          'public': 48,
#          'wood': 72,
#          'barrior': 1,
#          'animal': 96,
#          'bird': 191,
#          'seeds': 6,
#          'someone': 72,
#          'sunflower': 1,
#          'clinging': 5,
#          'finger': 36,
#          'wades': 12,
#          'guided': 3,
#          'laughs': 33,
#          'playful': 7,
#          'this': 23,
#          'beige': 54,
#          'torwards': 1,
#          'outdoor': 136,
#          'handstand': 48,
#          'does': 232,
#          'sheets': 5,
#          'upside': 96,
#          'snowboard': 88,
#          'surfboard': 146,
#          'bikes': 86,
#          'traveling': 16,
#          'worn': 5,
#          'motorcycles': 27,
#          'motorbikes': 7,
#          'follow': 14,
#          'dirt-bikes': 1,
#          'off-road': 10,
#          'garment': 2,
#          'flag': 98,
#          'crescent': 1,
#          'moon': 5,
#          'star': 9,
#          'gown': 9,
#          'Muslim': 3,
#          'helps': 28,
#          'wave': 317,
#          'Baby': 14,
#          'half': 31,
#          'naked': 46,
#          'chair': 132,
#          'older': 205,
#          'back': 378,
#          'relaxes': 12,
#          'adobe': 1,
#          'where': 34,
#          'bicycles': 54,
#          'propped': 4,
#          'cap': 195,
#          'close': 43,
#          'parked': 41,
#          'relaxing': 15,
#          'folding': 11,
#          '"Topless': 2,
#          'slippers': 2,
#          'navy': 14,
#          'reclining': 2,
#          'hauling': 1,
#          'Both': 2,
#          'retrieve': 9,
#          'mouths': 40,
#          'tug': 30,
#          'chew': 16,
#          '"There': 43,
#          'haired': 145,
#          'bottled': 2,
#          'drink': 106,
#          'tilted': 4,
#          'spiked': 4,
#          'party': 56,
#          'streets': 28,
#          'they': 116,
#          'women': 612,
#          'parade': 68,
#          'neck-deep': 1,
#          'vegetation': 4,
#          'filled': 44,
#          '"Brown': 14,
#          'bushes': 37,
#          'creating': 8,
#          'splash': 44,
#          'seaweed': 11,
#          'lav': 1,
#          'swimmers': 10,
#          'kelp': 1,
#          'foreground': 40,
#          'sandals': 21,
#          'short': 69,
#          'sleeved': 14,
#          'pinstripe': 2,
#          'snows': 4,
#          'furry': 59,
#          'attempts': 56,
#          'itself': 20,
#          'self': 5,
#          'backpacks': 32,
#          'placed': 9,
#          'cardboard': 27,
#          'bus': 81,
#          'station': 34,
#          'bouncing': 29,
#          'folded': 9,
#          'beds': 3,
#          'bedroom': 5,
#          'snowboarder': 220,
#          'slope': 76,
#          'boarders': 1,
#          'Snowboarders': 3,
#          'slopes': 7,
#          'clothing': 130,
#          'store': 111,
#          ...})

# %%
#Visualise the top 30 occuring words in the captions

#write your code here
most_occur = val_count.most_common(30)

print(most_occur)
# Out:
# [('a', 40271), ('.', 34212), ('A', 21481), ('in', 18961), ('the', 15328), ('on', 10729), ('is', 9345), ('and', 8850), ('dog', 7982), ('with', 7760), ('man', 6828), ('of', 6712), ('Two', 3962), ('white', 3875), ('black', 3696), ('are', 3503), ('boy', 3442), ('woman', 3227), ('girl', 3217), (',', 3210), ('to', 3173), ('wearing', 3061), ('The', 2920), ('at', 2904), ('water', 2774), ('red', 2660), ('brown', 2475), ('people', 2442), ('young', 2431), ('."', 2365)]

# %%
import seaborn as sns

# %%
def get_top_words_based_on_cnt(words_dict,n_words):
    n_words+=1
    keys=list(words_dict.keys())
    values=list(words_dict.values())
    sorted_values=sorted(values,reverse=True)[:n_words]
    sorted_keys=[]
    for i in sorted_values:
        if sorted_values.count(i)==1:
            sorted_keys.append(keys[values.index(i)])
        elif sorted_values.count(i)==2:
            f_idx=values.index(i)
            s_idx=values[f_idx+1:].index(i)
            s_idx+=f_idx+1
            a,b=keys[f_idx],keys[s_idx]
            if a not in sorted_keys and b not in sorted_keys:
                sorted_keys.append(a)
                sorted_keys.append(b)
    plt.figure(figsize=(10,6))
    sns.barplot(x=sorted_keys,y=sorted_values)
    plt.xticks(rotation=60)
    plt.show()
    #write your code here
get_top_words_based_on_cnt(val_count,30)

# %%
#Create a list which contains all the captions
annotations=list(capdf['Captions'])

#add the <start> & <end> token to all those captions as well
annotations = capdf.Captions.apply(lambda s:"<start>"+" "+s+" "+"<end>")

#Create a list which contains all the path to the images
all_img_path=list(capdf['Path'])
print("Total captions present in the dataset: "+ str(len(annotations)))
print("Total images present in the dataset: " + str(len(all_img_path)))
# Out:
# Total captions present in the dataset: 40455
# Total images present in the dataset: 40455

# %% [markdown]
# ## Pre-Processing the captions
# 1.Create the tokenized vectors by tokenizing the captions fore ex :split them using spaces & other filters.
# This gives us a vocabulary of all of the unique words in the data. Keep the total vocaublary to top 5,000 words for saving memory.
#
# 2.Replace all other words with the unknown token "UNK" .
#
# 3.Create word-to-index and index-to-word mappings.
#
# 4.Pad all sequences to be the same length as the longest one.

# %%
# create the tokenizer

#your code here

topT = 5000
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=topT+1,oov_token="<unk>",filters='!"#$%&()*+.,-/:;=?@[\]^_`{|}~ ')
tokenizer.fit_on_texts(annotations)
train_seqs = tokenizer.texts_to_sequences(annotations)

tokenizer.word_index['<pad>'] = 0
tokenizer.index_word[0] = '<pad>'

# %%
annotations[:10]
# Out:
# 0    <start> A child in a pink dress is climbing up...
# 1    <start> A girl going into a wooden building . ...
# 2    <start> A little girl climbing into a wooden p...
# 3    <start> A little girl climbing the stairs to h...
# 4    <start> A little girl in a pink dress going in...
# 5    <start> A black dog and a spotted dog are figh...
# 6    <start> A black dog and a tri-colored dog play...
# 7    <start> A black dog and a white dog with brown...
# 8    <start> Two dogs of different breeds looking a...
# 9    <start> Two dogs on pavement moving toward eac...
# Name: Captions, dtype: object

# %%
train_seqs[:10]
# Out:
# [[3, 2, 44, 5, 2, 91, 173, 8, 120, 52, 2, 394, 13, 395, 5, 29, 1, 671, 4],
#  [3, 2, 20, 317, 65, 2, 197, 118, 4],
#  [3, 2, 41, 20, 120, 65, 2, 197, 2438, 4],
#  [3, 2, 41, 20, 120, 6, 395, 21, 61, 2438, 4],
#  [3, 2, 41, 20, 5, 2, 91, 173, 317, 65, 2, 197, 2982, 4],
#  [3, 2, 16, 10, 9, 2, 844, 10, 18, 344, 4],
#  [3, 2, 16, 10, 9, 2, 1576, 236, 10, 35, 11, 138, 83, 7, 6, 152, 4],
#  [3, 2, 16, 10, 9, 2, 15, 10, 11, 28, 1002, 18, 641, 23, 138, 83, 5, 6, 73, 4],
#  [3, 14, 32, 13, 742, 2654, 90, 23, 138, 83, 7, 6, 152, 4],
#  [3, 14, 32, 7, 728, 806, 322, 138, 83, 4]]

# %%
tokenizer.oov_token
# Out:
# '<unk>'

# %%
tokenizer.index_word
# Out:
# {1: '<unk>',
#  2: 'a',
#  3: '<start>',
#  4: '<end>',
#  5: 'in',
#  6: 'the',
#  7: 'on',
#  8: 'is',
#  9: 'and',
#  10: 'dog',
#  11: 'with',
#  12: 'man',
#  13: 'of',
#  14: 'two',
#  15: 'white',
#  16: 'black',
#  17: 'boy',
#  18: 'are',
#  19: 'woman',
#  20: 'girl',
#  21: 'to',
#  22: 'wearing',
#  23: 'at',
#  24: 'people',
#  25: 'water',
#  26: 'red',
#  27: 'young',
#  28: 'brown',
#  29: 'an',
#  30: 'his',
#  31: 'blue',
#  32: 'dogs',
#  33: 'running',
#  34: 'through',
#  35: 'playing',
#  36: 'while',
#  37: 'shirt',
#  38: 'down',
#  39: 'standing',
#  40: 'ball',
#  41: 'little',
#  42: 'grass',
#  43: 'snow',
#  44: 'child',
#  45: 'person',
#  46: 'jumping',
#  47: 'over',
#  48: 'three',
#  49: 'front',
#  50: 'sitting',
#  51: 'holding',
#  52: 'up',
#  53: 'field',
#  54: 'small',
#  55: 'by',
#  56: 'large',
#  57: 'green',
#  58: 'one',
#  59: 'group',
#  60: 'yellow',
#  61: 'her',
#  62: 'walking',
#  63: 'children',
#  64: 'men',
#  65: 'into',
#  66: 'air',
#  67: 'beach',
#  68: 'near',
#  69: 'mouth',
#  70: 'jumps',
#  71: 'another',
#  72: 'for',
#  73: 'street',
#  74: 'runs',
#  75: 'its',
#  76: 'from',
#  77: 'riding',
#  78: 'stands',
#  79: 'as',
#  80: 'bike',
#  81: 'girls',
#  82: 'outside',
#  83: 'other',
#  84: 'off',
#  85: 'out',
#  86: 'rock',
#  87: 'next',
#  88: 'play',
#  89: 'orange',
#  90: 'looking',
#  91: 'pink',
#  92: 'player',
#  93: 'camera',
#  94: 'their',
#  95: 'pool',
#  96: 'hat',
#  97: 'jacket',
#  98: 'boys',
#  99: 'women',
#  100: 'around',
#  101: 'behind',
#  102: 'some',
#  103: 'background',
#  104: 'dirt',
#  105: 'toy',
#  106: 'soccer',
#  107: 'sits',
#  108: 'dressed',
#  109: 'has',
#  110: 'wall',
#  111: 'mountain',
#  112: 'walks',
#  113: 'crowd',
#  114: 'along',
#  115: 'plays',
#  116: 'stand',
#  117: 'looks',
#  118: 'building',
#  119: 'park',
#  120: 'climbing',
#  121: 'four',
#  122: 'top',
#  123: 'face',
#  124: 'football',
#  125: 'across',
#  126: 'grassy',
#  127: 'holds',
#  128: 'sand',
#  129: 'stick',
#  130: 'smiling',
#  131: 'ocean',
#  132: 'rides',
#  133: 'swimming',
#  134: 'hill',
#  135: 'skateboard',
#  136: 'carrying',
#  137: 'doing',
#  138: 'each',
#  139: 'tennis',
#  140: 'car',
#  141: 'tree',
#  142: 'snowy',
#  143: 'baby',
#  144: 'picture',
#  145: 'bicycle',
#  146: 'hair',
#  147: 'together',
#  148: 'jump',
#  149: 'him',
#  150: 'it',
#  151: "'s",
#  152: 'road',
#  153: 'area',
#  154: 'that',
#  155: 'basketball',
#  156: 'tan',
#  157: 'back',
#  158: 'trick',
#  159: 'race',
#  160: 'swing',
#  161: 'head',
#  162: 'shorts',
#  163: 'bench',
#  164: 'sidewalk',
#  165: 'covered',
#  166: 'run',
#  167: 'catch',
#  168: 'game',
#  169: 'sit',
#  170: 'helmet',
#  171: 'ground',
#  172: 'hand',
#  173: 'dress',
#  174: 'something',
#  175: 'fence',
#  176: 'kids',
#  177: 'being',
#  178: 'frisbee',
#  179: 'lake',
#  180: 'path',
#  181: 'city',
#  182: 'ramp',
#  183: 'walk',
#  184: 'wave',
#  185: 'skateboarder',
#  186: 'several',
#  187: 'long',
#  188: 'purple',
#  189: 'side',
#  190: 'there',
#  191: 'slide',
#  192: 'baseball',
#  193: 'high',
#  194: 'posing',
#  195: 'track',
#  196: 'players',
#  197: 'wooden',
#  198: 'big',
#  199: 'sunglasses',
#  200: 'watches',
#  201: 'boat',
#  202: 'uniform',
#  203: 'dark',
#  204: 'coat',
#  205: 'trees',
#  206: 'look',
#  207: 'them',
#  208: 'pants',
#  209: 'table',
#  210: 'rocks',
#  211: 'ride',
#  212: 'rope',
#  213: 'watching',
#  214: 'motorcycle',
#  215: 'grey',
#  216: 'suit',
#  217: 'couple',
#  218: 'towards',
#  219: 'arms',
#  220: 'beside',
#  221: 'hands',
#  222: 'under',
#  223: 'rocky',
#  224: 'sign',
#  225: 'watch',
#  226: 'snowboarder',
#  227: 'river',
#  228: 'horse',
#  229: 'does',
#  230: 'above',
#  231: 'racing',
#  232: 'older',
#  233: 'jeans',
#  234: 'lady',
#  235: 'ice',
#  236: 'colored',
#  237: 'striped',
#  238: 'colorful',
#  239: 'pose',
#  240: 'who',
#  241: 'onto',
#  242: 'woods',
#  243: 'midair',
#  244: 'guy',
#  245: 'he',
#  246: 'glasses',
#  247: 'taking',
#  248: 'leaps',
#  249: 'mountains',
#  250: 'haired',
#  251: 'asian',
#  252: 'climbs',
#  253: 'playground',
#  254: 'blonde',
#  255: 'yard',
#  256: 'against',
#  257: 'collar',
#  258: 'performing',
#  259: 'cliff',
#  260: 'hockey',
#  261: 'cap',
#  262: 'blond',
#  263: 'bird',
#  264: 'smiles',
#  265: 'body',
#  266: 'open',
#  267: 'laying',
#  268: 'surfer',
#  269: 'team',
#  270: 'many',
#  271: 'rider',
#  272: 'after',
#  273: 'chasing',
#  274: 'kid',
#  275: 'wet',
#  276: 'fountain',
#  277: 'skier',
#  278: 'surrounded',
#  279: 'outdoors',
#  280: 'flying',
#  281: 'during',
#  282: 'inside',
#  283: 'old',
#  284: 'brick',
#  285: 'biker',
#  286: 'others',
#  287: 'shore',
#  288: 'edge',
#  289: 'away',
#  290: 'takes',
#  291: 'light',
#  292: 'toddler',
#  293: 'guitar',
#  294: 't',
#  295: 'hanging',
#  296: 'trying',
#  297: 'very',
#  298: 'middle',
#  299: 'someone',
#  300: 'forest',
#  301: 'five',
#  302: 'backpack',
#  303: 'night',
#  304: 'outfit',
#  305: 'gray',
#  306: 'pole',
#  307: 'bed',
#  308: 'talking',
#  309: 'object',
#  310: 'steps',
#  311: 'making',
#  312: 'floor',
#  313: 'nearby',
#  314: 'whilst',
#  315: 'line',
#  316: 'about',
#  317: 'going',
#  318: 'flowers',
#  319: 'past',
#  320: 'arm',
#  321: 'sky',
#  322: 'toward',
#  323: 'tall',
#  324: 'trail',
#  325: 'surfboard',
#  326: 'swinging',
#  327: 'eating',
#  328: 'dancing',
#  329: 'board',
#  330: 'waves',
#  331: 'this',
#  332: 'poses',
#  333: 'bridge',
#  334: 'leaves',
#  335: 'all',
#  336: 'day',
#  337: 'leaping',
#  338: 'window',
#  339: 'outdoor',
#  340: 'bag',
#  341: 'course',
#  342: 'clothes',
#  343: 'legs',
#  344: 'fighting',
#  345: 'chair',
#  346: 'room',
#  347: 'costume',
#  348: 'house',
#  349: 'leash',
#  350: 'plastic',
#  351: 'shallow',
#  352: 'clothing',
#  353: 'splashing',
#  354: 'stone',
#  355: 'carries',
#  356: 'shirts',
#  357: 'ready',
#  358: 'climber',
#  359: 'between',
#  360: 'obstacle',
#  361: 'getting',
#  362: 'bright',
#  363: 'catches',
#  364: 'sliding',
#  365: 'adult',
#  366: 'they',
#  367: 'swings',
#  368: 'skateboarding',
#  369: 'bathing',
#  370: 'sweater',
#  371: 'concrete',
#  372: 'waiting',
#  373: 'sled',
#  374: 'trampoline',
#  375: 'lawn',
#  376: 'gear',
#  377: 'winter',
#  378: 'wears',
#  379: 'metal',
#  380: 'mud',
#  381: 'skiing',
#  382: 'uniforms',
#  383: 'male',
#  384: 'jersey',
#  385: 'railing',
#  386: 'number',
#  387: 'sandy',
#  388: 'tongue',
#  389: 'fire',
#  390: 'stream',
#  391: 'store',
#  392: 'golden',
#  393: 'pulling',
#  394: 'set',
#  395: 'stairs',
#  396: 'catching',
#  397: 'distance',
#  398: 'throwing',
#  399: 'upside',
#  400: 'sun',
#  401: 'train',
#  402: 'lot',
#  403: 'drink',
#  404: 'bar',
#  405: 'get',
#  406: 'fishing',
#  407: 'gets',
#  408: 'tries',
#  409: 'adults',
#  410: 'smile',
#  411: 'shirtless',
#  412: 'overlooking',
#  413: 'like',
#  414: 'swims',
#  415: 'flies',
#  416: 'rail',
#  417: 'ski',
#  418: 'female',
#  419: 'couch',
#  420: 'wooded',
#  421: 'tricks',
#  422: 'makes',
#  423: 'busy',
#  424: 'drinking',
#  425: 'puppy',
#  426: 'chases',
#  427: 'lying',
#  428: 'animal',
#  429: 'tire',
#  430: 'vest',
#  431: 'flag',
#  432: 'surfing',
#  433: 'swim',
#  434: 'performs',
#  435: 'american',
#  436: 'cellphone',
#  437: 'pond',
#  438: 'reading',
#  439: 'laughing',
#  440: 'right',
#  441: 'trunks',
#  442: 'leaning',
#  443: 'flip',
#  444: 'shopping',
#  445: 'huge',
#  446: 'food',
#  447: 'puddle',
#  448: 'dock',
#  449: 'she',
#  450: 'slides',
#  451: 'horses',
#  452: 'eyes',
#  453: 'hats',
#  454: 'photo',
#  455: 'bat',
#  456: 'shoes',
#  457: 'nose',
#  458: 'sunset',
#  459: 'left',
#  460: 'kayak',
#  461: 'bubbles',
#  462: 'cart',
#  463: 'truck',
#  464: 'climb',
#  465: 'coming',
#  466: 'stunt',
#  467: 'deep',
#  468: 'snowboard',
#  469: 'hold',
#  470: 'scarf',
#  471: 'feet',
#  472: 'life',
#  473: 'no',
#  474: 'or',
#  475: 'bikes',
#  476: 'family',
#  477: 'umbrella',
#  478: 'waterfall',
#  479: 'goal',
#  480: 'view',
#  481: 'elderly',
#  482: 'equipment',
#  483: 'restaurant',
#  484: 'tent',
#  485: 'skating',
#  486: 'hurdle',
#  487: 'greyhound',
#  488: 'biting',
#  489: 'both',
#  490: 'skis',
#  491: 'lone',
#  492: 'setting',
#  493: 'harness',
#  494: 'take',
#  495: 'falling',
#  496: 'wetsuit',
#  497: 'bus',
#  498: 'mask',
#  499: 'muddy',
#  500: 'hiker',
#  501: 'flags',
#  502: 'vehicle',
#  503: 'dry',
#  504: 'paper',
#  505: 'skirt',
#  506: 'bags',
#  507: 'guys',
#  508: 'court',
#  509: 'surf',
#  510: 'crowded',
#  511: 'fight',
#  512: 'sweatshirt',
#  513: 'dresses',
#  514: 'structure',
#  515: 'ledge',
#  516: 'book',
#  517: 'tank',
#  518: 'bmx',
#  519: 'six',
#  520: 'be',
#  521: 'pile',
#  522: 'slope',
#  523: 'go',
#  524: 'cigarette',
#  525: 'german',
#  526: 'raft',
#  527: 'airborne',
#  528: 'short',
#  529: 'driving',
#  530: 'skate',
#  531: 'kick',
#  532: 'have',
#  533: 'diving',
#  534: 'faces',
#  535: 'cross',
#  536: 'cement',
#  537: 'inflatable',
#  538: 'goggles',
#  539: 'wood',
#  540: 'costumes',
#  541: 'graffiti',
#  542: 'goes',
#  543: 'canoe',
#  544: 'parking',
#  545: 'teenage',
#  546: 'cyclist',
#  547: 'subway',
#  548: 'dance',
#  549: 'kicking',
#  550: 'bottle',
#  551: 'shaking',
#  552: 'splashes',
#  553: 'buildings',
#  554: 'fallen',
#  555: 'turn',
#  556: 'parade',
#  557: 'hit',
#  558: 'shepherd',
#  559: 'ears',
#  560: 'ring',
#  561: 'sports',
#  562: 'jackets',
#  563: 'gathered',
#  564: 'blanket',
#  565: 'pictures',
#  566: 'low',
#  567: 'backyard',
#  568: 'throws',
#  569: 'smaller',
#  570: 'closeup',
#  571: 'tunnel',
#  572: 'band',
#  573: 'full',
#  574: 'silver',
#  575: 'chairs',
#  576: 'microphone',
#  577: 'smoking',
#  578: 'leather',
#  579: 'held',
#  580: 'sunny',
#  581: 'bikini',
#  582: 'wheel',
#  583: 'piece',
#  584: 'boots',
#  585: 'event',
#  586: 'balls',
#  587: 'beard',
#  588: 'bull',
#  589: 'surface',
#  590: 'cars',
#  591: 'cat',
#  592: 'fluffy',
#  593: 'stage',
#  594: 'kicks',
#  595: 'painted',
#  596: 'make',
#  597: 'pushing',
#  598: 'using',
#  599: 'bicyclist',
#  600: 'hiking',
#  601: 'outfits',
#  602: 'box',
#  603: 'rugby',
#  604: 'statue',
#  605: 'stuffed',
#  606: 'pointing',
#  607: 'paint',
#  608: 'sticks',
#  609: 'steep',
#  610: 'gold',
#  611: 'bald',
#  612: 'bucket',
#  613: 'blowing',
#  614: 'glass',
#  615: 'tube',
#  616: 'door',
#  617: 'swimsuit',
#  618: 'drinks',
#  619: 'scooter',
#  620: 'suits',
#  621: 'sleeping',
#  622: 'flower',
#  623: 'throw',
#  624: 'shot',
#  625: 'volleyball',
#  626: 'cow',
#  627: 'furry',
#  628: 'hugging',
#  629: 'corner',
#  630: 'wrestling',
#  631: 'net',
#  632: 'crossing',
#  633: 'wrestle',
#  634: 'same',
#  635: 'hangs',
#  636: 'hind',
#  637: 'cowboy',
#  638: 'points',
#  639: 'leg',
#  640: 'motorcyclist',
#  641: 'staring',
#  642: 'leans',
#  643: 'attempting',
#  644: 'police',
#  645: 'kissing',
#  646: 'spectators',
#  647: 'lays',
#  648: 'wading',
#  649: 'sheep',
#  650: 'party',
#  651: 'attempts',
#  652: 'few',
#  653: 'teams',
#  654: 'show',
#  655: 'bunch',
#  656: 'log',
#  657: 'facing',
#  658: 'below',
#  659: 'beige',
#  660: 'bicycles',
#  661: 'close',
#  662: 'puppies',
#  663: 'cup',
#  664: 'snowboarding',
#  665: 'hoop',
#  666: 'desert',
#  667: 'garden',
#  668: 'african',
#  669: 'wide',
#  670: 'fenced',
#  671: 'way',
#  672: 'sprinkler',
#  673: 'fast',
#  674: 'beautiful',
#  675: 'sticking',
#  676: 'underwater',
#  677: 'attached',
#  678: 'fish',
#  679: 'gym',
#  680: 'softball',
#  681: 'gather',
#  682: 'competition',
#  683: 'eats',
#  684: 'waving',
#  685: 'end',
#  686: 'onlookers',
#  687: 'naked',
#  688: 'filled',
#  689: 'phone',
#  690: 'wings',
#  691: 'poles',
#  692: 'racket',
#  693: 'racetrack',
#  694: 'which',
#  695: 'dances',
#  696: 'talks',
#  697: 'rain',
#  698: 'gravel',
#  699: 'base',
#  700: 'rolling',
#  701: 'prepares',
#  702: 'seat',
#  703: 'lit',
#  704: 'empty',
#  705: 'clear',
#  706: 'motocross',
#  707: 'racer',
#  708: 'seated',
#  709: 'hula',
#  710: 'do',
#  711: 'headband',
#  712: 'signs',
#  713: 'toys',
#  714: 'heads',
#  715: 'neck',
#  716: 'wear',
#  717: 'hits',
#  718: 'ladies',
#  719: 'pushes',
#  720: 'plaid',
#  721: 'branch',
#  722: 'mohawk',
#  723: 'market',
#  724: 'downhill',
#  725: 'birds',
#  726: 'bride',
#  727: 'round',
#  728: 'pavement',
#  729: 'platform',
#  730: 'paddling',
#  731: 'having',
#  732: 'public',
#  733: 'handstand',
#  734: 'just',
#  735: 'shop',
#  736: 'traffic',
#  737: 'rough',
#  738: 'shoulder',
#  739: 'scene',
#  740: 'among',
#  741: 'skateboards',
#  742: 'different',
#  743: 'reads',
#  744: 'bearded',
#  745: 'gloves',
#  746: 'chewing',
#  747: 'school',
#  748: 'beer',
#  749: 'hose',
#  750: 'thrown',
#  751: 'landscape',
#  752: 'rural',
#  753: 'drives',
#  754: 'dirty',
#  755: 'bars',
#  756: 'barefoot',
#  757: 'tie',
#  758: 'urban',
#  759: 'kitchen',
#  760: 'teeth',
#  761: 'races',
#  762: 'cream',
#  763: 'balloon',
#  764: 'resting',
#  765: 'foot',
#  766: 'tug',
#  767: 'splash',
#  768: 'display',
#  769: 'carnival',
#  770: 'before',
#  771: 'bottom',
#  772: 'cricket',
#  773: 'painting',
#  774: 'lies',
#  775: 'paved',
#  776: 'goalie',
#  777: 'wait',
#  778: 'indoor',
#  779: 'mother',
#  780: 'plants',
#  781: 'carpet',
#  782: 'creek',
#  783: 'says',
#  784: 'waits',
#  785: 'younger',
#  786: 'rapids',
#  787: 'wedding',
#  788: 'flight',
#  789: 'smoke',
#  790: 'match',
#  791: 'opposing',
#  792: 'lined',
#  793: 'half',
#  794: 'headphones',
#  795: 'animals',
#  796: 'pipe',
#  797: 'lap',
#  798: 'fall',
#  799: 'showing',
#  800: 'block',
#  801: 'stadium',
#  802: 'skates',
#  803: 'greyhounds',
#  804: 'blows',
#  805: 'wrestler',
#  806: 'moving',
#  807: 'boats',
#  808: 'gun',
#  809: 'parked',
#  810: 'reaching',
#  811: 'onstage',
#  812: 'santa',
#  813: 'art',
#  814: 'seen',
#  815: 'paddle',
#  816: 'video',
#  817: 'where',
#  818: 'mouths',
#  819: 'foreground',
#  820: 'war',
#  821: 'talk',
#  822: 'chase',
#  823: 'bandanna',
#  824: 'third',
#  825: 'instruments',
#  826: 'singing',
#  827: 'lights',
#  828: 'runner',
#  829: 'falls',
#  830: 'can',
#  831: 'deck',
#  832: 'atv',
#  833: 'helmets',
#  834: 'pulled',
#  835: 'photograph',
#  836: 'ear',
#  837: 'motorbike',
#  838: 'wire',
#  839: 'funny',
#  840: 'matching',
#  841: 'poodle',
#  842: 'curly',
#  843: 'shooting',
#  844: 'spotted',
#  845: 'ropes',
#  846: 'newspaper',
#  847: 'outstretched',
#  848: 'floating',
#  849: 'fly',
#  850: 'audience',
#  851: 'brightly',
#  852: 'hitting',
#  853: 'fair',
#  854: 'try',
#  855: 'unicycle',
#  856: 'reaches',
#  857: 'amusement',
#  858: 'hay',
#  859: 'staircase',
#  860: 'christmas',
#  861: 'shakes',
#  862: 'duck',
#  863: 'hole',
#  864: 'atop',
#  865: 'spray',
#  866: 'bushes',
#  867: 'preparing',
#  868: 'bank',
#  869: 'alongside',
#  870: 'purse',
#  871: 'retriever',
#  872: 'pack',
#  873: 'martial',
#  874: 'shoulders',
#  875: 'wheelie',
#  876: 'raises',
#  877: 'bubble',
#  878: 'teenagers',
#  879: 'giant',
#  880: 'grinding',
#  881: 'appears',
#  882: 'terrain',
#  883: 'country',
#  884: 'skiers',
#  885: 'finger',
#  886: 'hooded',
#  887: 'stop',
#  888: 'follows',
#  889: 'formation',
#  890: 'chain',
#  891: 'roller',
#  892: 'plate',
#  893: 'pulls',
#  894: 'hoops',
#  895: 'kite',
#  896: 'digging',
#  897: 'larger',
#  898: 'surfs',
#  899: 'muzzle',
#  900: 'rowing',
#  901: 'putting',
#  902: 'hikers',
#  903: 'alone',
#  904: 'denim',
#  905: 'enjoys',
#  906: 'cold',
#  907: 'hoodie',
#  908: 'music',
#  909: 'balancing',
#  910: 'jeep',
#  911: 'covering',
#  912: 'perform',
#  913: 'muzzled',
#  914: 'rodeo',
#  915: 'row',
#  916: 'kneeling',
#  917: 'paddles',
#  918: 'puts',
#  919: 'pier',
#  920: 'station',
#  921: 'giving',
#  922: 'shaggy',
#  923: 'picnic',
#  924: 'backwards',
#  925: 'gives',
#  926: 'indoors',
#  927: 'spinning',
#  928: 'himself',
#  929: 'shadow',
#  930: 'parachute',
#  931: 'jumped',
#  932: 'hang',
#  933: 'break',
#  934: 'shows',
#  935: 'handrail',
#  936: 'laughs',
#  937: 'leap',
#  938: 'bite',
#  939: 'backs',
#  940: 'cut',
#  941: 'safety',
#  942: 'pull',
#  943: 'playfully',
#  944: 'clouds',
#  945: 'backpacks',
#  946: 'writing',
#  947: 'ladder',
#  948: 'enjoying',
#  949: 'owner',
#  950: 'competing',
#  951: 'necklace',
#  952: 'gate',
#  953: 'counter',
#  954: 'sniffing',
#  955: 'licking',
#  956: 'riders',
#  957: 'terrier',
#  958: 'seven',
#  959: 'bites',
#  960: 'construction',
#  961: 'machine',
#  962: 'fetch',
#  963: 'bikers',
#  964: 'skinned',
#  965: 'underneath',
#  966: 'jungle',
#  967: 'made',
#  968: 'cloth',
#  969: 'fur',
#  970: 'mound',
#  971: 'basket',
#  972: 'violin',
#  973: 'doorway',
#  974: 'fingers',
#  975: 'passing',
#  976: 'tackle',
#  977: 'bowl',
#  978: 'rink',
#  979: 'crouches',
#  980: 'quickly',
#  981: 'paws',
#  982: 'sea',
#  983: 'mid',
#  984: 'collie',
#  985: 'step',
#  986: 'computer',
#  987: 'camouflage',
#  988: 'these',
#  989: 'splashed',
#  990: 'hillside',
#  991: 'referee',
#  992: 'taken',
#  993: 'coats',
#  994: 'professional',
#  995: 'rollerblades',
#  996: 'decorated',
#  997: 'friend',
#  998: 'pigeons',
#  999: 'ducks',
#  1000: 'military',
#  ...}

# %%
tokenizer.word_counts
# Out:
# OrderedDict([('<start>', 40455),
#              ('a', 62992),
#              ('child', 1545),
#              ('in', 18986),
#              ('pink', 739),
#              ('dress', 348),
#              ('is', 9345),
#              ('climbing', 507),
#              ('up', 1302),
#              ('set', 109),
#              ('of', 6723),
#              ('stairs', 109),
#              ('an', 2432),
#              ('entry', 1),
#              ('way', 53),
#              ('<end>', 40455),
#              ('girl', 3328),
#              ('going', 149),
#              ('into', 1074),
#              ('wooden', 284),
#              ('building', 510),
#              ('little', 1768),
#              ('playhouse', 6),
#              ('the', 18419),
#              ('to', 3176),
#              ('her', 1178),
#              ('cabin', 4),
#              ('black', 3848),
#              ('dog', 8138),
#              ('and', 8862),
#              ('spotted', 38),
#              ('are', 3504),
#              ('fighting', 133),
#              ('tri', 14),
#              ('colored', 221),
#              ('playing', 2008),
#              ('with', 7765),
#              ('each', 430),
#              ('other', 773),
#              ('on', 10745),
#              ('road', 398),
#              ('white', 3959),
#              ('brown', 2578),
#              ('spots', 29),
#              ('staring', 57),
#              ('at', 2915),
#              ('street', 944),
#              ('two', 5642),
#              ('dogs', 2125),
#              ('different', 46),
#              ('breeds', 5),
#              ('looking', 743),
#              ('pavement', 48),
#              ('moving', 41),
#              ('toward', 146),
#              ('covered', 372),
#              ('paint', 62),
#              ('sits', 577),
#              ('front', 1386),
#              ('painted', 64),
#              ('rainbow', 22),
#              ('hands', 246),
#              ('bowl', 30),
#              ('sitting', 1368),
#              ('large', 1236),
#              ('small', 1278),
#              ('grass', 1622),
#              ('plays', 526),
#              ('fingerpaints', 3),
#              ('canvas', 6),
#              ('it', 401),
#              ('there', 304),
#              ('pigtails', 14),
#              ('painting', 43),
#              ('young', 2630),
#              ('outside', 791),
#              ('man', 7274),
#              ('lays', 56),
#              ('bench', 375),
#              ('while', 1968),
#              ('his', 2357),
#              ('by', 1249),
#              ('him', 403),
#              ('which', 51),
#              ('also', 20),
#              ('tied', 15),
#              ('sleeping', 60),
#              ('next', 749),
#              ('shirtless', 104),
#              ('lies', 43),
#              ('park', 508),
#              ('laying', 189),
#              ('holding', 1324),
#              ('leash', 131),
#              ('ground', 357),
#              ('orange', 745),
#              ('hat', 682),
#              ('starring', 8),
#              ('something', 346),
#              ('wears', 115),
#              ('glasses', 206),
#              ('gauges', 2),
#              ('wearing', 3062),
#              ('blitz', 1),
#              ('beer', 45),
#              ('can', 39),
#              ('crocheted', 1),
#              ('pierced', 6),
#              ('ears', 69),
#              ('rope', 251),
#              ('net', 58),
#              ('red', 2691),
#              ('roping', 2),
#              ('climbs', 201),
#              ('bridge', 141),
#              ('grips', 2),
#              ('onto', 211),
#              ('ropes', 38),
#              ('playground', 201),
#              ('running', 2073),
#              ('grassy', 474),
#              ('garden', 54),
#              ('surrounded', 178),
#              ('fence', 340),
#              ('through', 2032),
#              ('boston', 9),
#              ('terrier', 31),
#              ('lush', 8),
#              ('green', 1234),
#              ('runs', 925),
#              ('near', 1025),
#              ('shakes', 37),
#              ('its', 925),
#              ('head', 377),
#              ('shore', 170),
#              ('ball', 1783),
#              ('edge', 170),
#              ('beach', 1046),
#              ('feet', 87),
#              ('stands', 869),
#              ('shaking', 71),
#              ('off', 766),
#              ('water', 2790),
#              ('standing', 1787),
#              ('turned', 20),
#              ('one', 1222),
#              ('side', 306),
#              ('boy', 3581),
#              ('smiles', 192),
#              ('stony', 3),
#              ('wall', 557),
#              ('city', 319),
#              ('overalls', 24),
#              ('working', 24),
#              ('stone', 128),
#              ('aross', 1),
#              ('walking', 1165),
#              ('paved', 43),
#              ('metal', 115),
#              ('pole', 157),
#              ('behind', 633),
#              ('smiling', 464),
#              ('shirt', 1962),
#              ('blue', 2279),
#              ('jeans', 225),
#              ('rock', 759),
#              ('leaps', 204),
#              ('over', 1415),
#              ('log', 55),
#              ('grey', 249),
#              ('leaping', 138),
#              ('fallen', 70),
#              ('tree', 427),
#              ('mottled', 2),
#              ('collar', 198),
#              ('jumping', 1473),
#              ('jumped', 33),
#              ('stump', 28),
#              ('snow', 1547),
#              ('field', 1283),
#              ('surface', 65),
#              ('displaying', 5),
#              ('pictures', 67),
#              ('skier', 179),
#              ('skis', 82),
#              ('past', 148),
#              ('another', 956),
#              ('paintings', 5),
#              ('person', 1542),
#              ('framed', 7),
#              ('looks', 512),
#              ('trees', 261),
#              ('artwork', 4),
#              ('for', 949),
#              ('sale', 7),
#              ('collage', 2),
#              ('cliff', 195),
#              ('group', 1218),
#              ('people', 2883),
#              ('belays', 1),
#              ('seven', 31),
#              ('climbers', 27),
#              ('ascending', 8),
#              ('face', 486),
#              ('whilst', 152),
#              ('several', 314),
#              ('row', 34),
#              ('watches', 276),
#              ('holds', 471),
#              ('line', 152),
#              ('chases', 99),
#              ('from', 920),
#              ('sprinkler', 53),
#              ('lawn', 117),
#              ('hose', 45),
#              ('away', 170),
#              ('prepares', 50),
#              ('catch', 368),
#              ('thrown', 45),
#              ('object', 155),
#              ('nearby', 153),
#              ('cars', 65),
#              ('about', 152),
#              ('yellow', 1217),
#              ('mouth', 989),
#              ('toy', 582),
#              ('ready', 125),
#              ('flying', 174),
#              ('air', 1062),
#              ('after', 184),
#              ('get', 107),
#              ('jumps', 979),
#              ('towards', 247),
#              ('trying', 163),
#              ('midair', 210),
#              ('woman', 3402),
#              ('waters', 29),
#              ('big', 280),
#              ('lake', 332),
#              ('lone', 82),
#              ('duck', 37),
#              ('swimming', 446),
#              ('around', 648),
#              ('watching', 251),
#              ('waves', 142),
#              ('hand', 349),
#              ('facing', 55),
#              ('skyline', 15),
#              ('couple', 248),
#              ('infant', 15),
#              ('being', 338),
#              ('held', 66),
#              ('male', 114),
#              ('pond', 96),
#              ('stroller', 28),
#              ('sit', 360),
#              ('baby', 419),
#              ('their', 693),
#              ('newborn', 8),
#              ('under', 246),
#              ('care', 3),
#              ('along', 527),
#              ('body', 192),
#              ('outdoors', 175),
#              ('surf', 78),
#              ('lab', 24),
#              ('tags', 7),
#              ('frolicks', 2),
#              ('splashes', 71),
#              ('this', 142),
#              ('splashing', 129),
#              ('drilling', 5),
#              ('hole', 37),
#              ('ice', 222),
#              ('frozen', 26),
#              ('men', 1121),
#              ('fishing', 107),
#              ('play', 747),
#              ('making', 154),
#              ('turn', 70),
#              ('soft', 13),
#              ('sand', 467),
#              ('together', 413),
#              ('tan', 394),
#              ('sandy', 111),
#              ('uses', 27),
#              ('picks', 12),
#              ('crampons', 1),
#              ('scale', 1),
#              ('climber', 125),
#              ('jacket', 678),
#              ('pants', 259),
#              ('scaling', 20),
#              ('waterfall', 85),
#              ('carries', 128),
#              ('as', 868),
#              ('he', 209),
#              ('walks', 552),
#              ('carrying', 434),
#              ('has', 562),
#              ('item', 20),
#              ('wet', 182),
#              ('kayak', 89),
#              ('life', 87),
#              ('jackets', 68),
#              ('rowing', 35),
#              ('canoe', 72),
#              ('gentle', 1),
#              ('ride', 255),
#              ('courtyard', 28),
#              ('catching', 109),
#              ('snaps', 1),
#              ('lunges', 6),
#              ('chocolate', 15),
#              ('too', 8),
#              ('late', 3),
#              ('captures', 1),
#              ('driveway', 15),
#              ('stick', 467),
#              ('kneeling', 34),
#              ('goalie', 43),
#              ('hockey', 195),
#              ('guarding', 9),
#              ('goal', 85),
#              ('kid', 183),
#              ('rink', 30),
#              ('right', 95),
#              ('crouches', 30),
#              ('modern', 5),
#              ('art', 40),
#              ('structure', 77),
#              ('glass', 61),
#              ('reads', 46),
#              ('newspaper', 38),
#              ('sculpture', 22),
#              ('office', 12),
#              ('statue', 63),
#              ('backpack', 159),
#              ('buildings', 71),
#              ('reading', 96),
#              ('tent', 84),
#              ('enter', 8),
#              ('setting', 82),
#              ('hut', 12),
#              ('iced', 3),
#              ('tarp', 8),
#              ('snowy', 422),
#              ('three', 1387),
#              ('hill', 445),
#              ('sky', 147),
#              ('them', 260),
#              ('stand', 519),
#              ('kneels', 26),
#              ('skyscraper', 6),
#              ('very', 163),
#              ('tall', 146),
#              ('distance', 109),
#              ('camera', 700),
#              ('bites', 31),
#              ('hard', 19),
#              ('treat', 16),
#              ('biting', 83),
#              ('baked', 2),
#              ('good', 7),
#              ('putting', 35),
#              ('both', 83),
#              ('eats', 52),
#              ('food', 93),
#              ('table', 258),
#              ('eating', 144),
#              ('pizza', 10),
#              ('tin', 1),
#              ('dish', 11),
#              ('mountainside', 26),
#              ('check', 7),
#              ('out', 763),
#              ('view', 85),
#              ('hilltop', 2),
#              ('overlooking', 104),
#              ('valley', 23),
#              ('hang', 33),
#              ('top', 488),
#              ('overlook', 6),
#              ('rest', 24),
#              ('ledge', 77),
#              ('above', 228),
#              ('moutains', 1),
#              ('down', 1843),
#              ('many', 185),
#              ('inflatable', 73),
#              ('boats', 41),
#              ('kayakers', 8),
#              ('railing', 113),
#              ('rafts', 6),
#              ('below', 55),
#              ('crowd', 531),
#              ('jersey', 114),
#              ('pose', 216),
#              ('some', 626),
#              ('multiracial', 1),
#              ('posing', 291),
#              ('picture', 419),
#              ('asian', 202),
#              ('blond', 194),
#              ('background', 595),
#              ('guy', 210),
#              ('striped', 220),
#              ('takeout', 1),
#              ('television', 9),
#              ('floor', 154),
#              ('fast', 53),
#              ('meal', 14),
#              ('someone', 161),
#              ('tv', 13),
#              ('teens', 7),
#              ('rail', 103),
#              ('crowded', 78),
#              ('takes', 170),
#              ('jump', 406),
#              ('skateboard', 435),
#              ('performing', 196),
#              ('trick', 385),
#              ('leans', 57),
#              ('skateboarder', 315),
#              ('doing', 434),
#              ('board', 143),
#              ('platform', 48),
#              ('skateboarders', 11),
#              ('paddling', 48),
#              ('river', 237),
#              ('seen', 40),
#              ('kayaking', 29),
#              ('paddles', 34),
#              ('boat', 276),
#              ('paddle', 40),
#              ('shallow', 130),
#              ('girls', 844),
#              ('ocean', 463),
#              ('four', 501),
#              ('children', 1156),
#              ('pajamas', 18),
#              ('have', 74),
#              ('pillow', 16),
#              ('fight', 78),
#              ('kids', 340),
#              ('bed', 157),
#              ('having', 48),
#              ('constructions', 1),
#              ('workers', 18),
#              ('beam', 21),
#              ('taking', 205),
#              ('break', 33),
#              ('construction', 31),
#              ('i', 17),
#              ('take', 81),
#              ('seat', 50),
#              ('steel', 4),
#              ('boys', 666),
#              ('puddle', 93),
#              ('balloon', 44),
#              ('mud', 115),
#              ('sunny', 66),
#              ('day', 139),
#              ('appears', 36),
#              ('wait', 43),
#              ('hailing', 1),
#              ('taxi', 4),
#              ('signaling', 1),
#              ('traffic', 47),
#              ('blonde', 201),
#              ('hair', 414),
#              ('tube', 61),
#              ('waving', 52),
#              ('arm', 148),
#              ('oncoming', 2),
#              ('brochure', 2),
#              ('train', 108),
#              ('rides', 458),
#              ('magizine', 1),
#              ('book', 77),
#              ('pamphlet', 1),
#              ('rocky', 245),
#              ('run', 369),
#              ('across', 476),
#              ('stones', 9),
#              ('area', 398),
#              ('descends', 11),
#              ('end', 52),
#              ('high', 293),
#              ('diving', 74),
#              ('pool', 692),
#              ('dive', 11),
#              ('window', 138),
#              ('overshirt', 1),
#              ('tank', 77),
#              ('chrome', 1),
#              ('door', 61),
#              ('puts', 34),
#              ('elevator', 7),
#              ('light', 169),
#              ('swim', 97),
#              ('shorts', 377),
#              ('trunks', 95),
#              ('arms', 247),
#              ('outstretched', 38),
#              ('hiker', 80),
#              ('bluff', 5),
#              ('mountains', 204),
#              ('ski', 103),
#              ("'s", 401),
#              ('landscape', 45),
#              ('mountain', 556),
#              ('beautiful', 53),
#              ('pauses', 10),
#              ('mountaintop', 25),
#              ('attempting', 57),
#              ('purple', 312),
#              ('low', 67),
#              ('cut', 32),
#              ('yard', 201),
#              ('frisbee', 337),
#              ('parking', 72),
#              ('lot', 108),
#              ('middle', 163),
#              ('during', 174),
#              ('heavy', 28),
#              ('mat', 22),
#              ('between', 125),
#              ('suv', 14),
#              ('pickup', 4),
#              ('open', 192),
#              ('busy', 100),
#              ('terrain', 36),
#              ('woolly', 1),
#              ('doberman', 17),
#              ('chasing', 184),
#              ('catches', 123),
#              ('tennis', 429),
#              ('multicolor', 11),
#              ('balloons', 28),
#              ('night', 159),
#              ('hot', 29),
#              ('lit', 50),
#              ('lined', 42),
#              ('nighttime', 12),
#              ('helmet', 358),
#              ('bike', 868),
#              ('miniature', 5),
#              ('dirt', 592),
#              ('bicycle', 418),
#              ('race', 382),
#              ('pedals', 3),
#              ('quickly', 30),
#              ('bmx', 77),
#              ('eight', 17),
#              ('gathered', 68),
#              ('dark', 269),
#              ('porch', 24),
#              ('darkened', 10),
#              ('room', 132),
#              ('throwing', 109),
#              ('cleans', 2),
#              ('bubbles', 89),
#              ('suds', 4),
#              ('wiped', 2),
#              ('clean', 7),
#              ('foam', 20),
#              ('ramp', 319),
#              ('soapy', 1),
#              ('getting', 124),
#              ('cleaned', 1),
#              ('slides', 92),
#              ('slide', 302),
#              ('wading', 56),
#              ('toys', 49),
#              ('floating', 38),
#              ('backyard', 67),
#              ('sliding', 123),
#              ('colorful', 218),
#              ('tubes', 2),
#              ('falling', 81),
#              ('wetsuit', 81),
#              ('toddler', 169),
#              ('waiting', 118),
#              ('come', 11),
#              ('so', 17),
#              ('droplets', 7),
#              ('fly', 38),
#              ('throws', 67),
#              ('sticks', 62),
#              ('tongue', 111),
#              ('make', 64),
#              ('faces', 74),
#              ('sticking', 53),
#              ('look', 261),
#              ('silly', 17),
#              ('horse', 233),
#              ('sweatshirt', 78),
#              ('fire', 111),
#              ('barrel', 22),
#              ('lead', 17),
#              ('horses', 92),
#              ('contained', 1),
#              ('bulldog', 9),
#              ('sheep', 56),
#              ('boxer', 18),
#              ('pushing', 64),
#              ('anouther', 1),
#              ('skinny', 18),
#              ('smaller', 67),
#              ('int', 6),
#              ('various', 19),
#              ('sizes', 4),
#              ('lady', 223),
#              ('no', 87),
#              ('dock', 93),
#              ('deck', 39),
#              ('closeup', 67),
#              ('that', 397),
#              ('paws', 30),
#              ('lying', 99),
#              ('resting', 44),
#              ('tiled', 9),
#              ('eyes', 92),
#              ('rests', 23),
#              ('patio', 21),
#              ('bricks', 5),
#              ('artificial', 10),
#              ('safety', 32),
#              ('harness', 82),
#              ('indoor', 43),
#              ('rocks', 257),
#              ('ring', 69),
#              ('jumphouse', 1),
#              ('teenage', 72),
#              ('seating', 7),
#              ('inflated', 5),
#              ('family', 86),
#              ('tractor', 10),
#              ('polaris', 3),
#              ('vehicle', 79),
#              ('played', 19),
#              ('wheeler', 21),
#              ('riding', 907),
#              ('atv', 39),
#              ('costume', 132),
#              ('left', 90),
#              ('sequined', 4),
#              ('feather', 12),
#              ('sidewalk', 375),
#              ('salmon', 2),
#              ('bikini', 66),
#              ('outfit', 159),
#              ('drinking', 100),
#              ('pop', 7),
#              ('approached', 2),
#              ('flamboyant', 3),
#              ('dressed', 570),
#              ('feathered', 8),
#              ('headress', 1),
#              ('skiiers', 9),
#              ('forest', 160),
#              ('skiing', 115),
#              ('wooded', 101),
#              ('cross', 74),
#              ('country', 36),
#              ('skiers', 36),
#              ('woodland', 21),
#              ('trail', 146),
#              ('woods', 211),
#              ('hikers', 35),
#              ('pathway', 12),
#              ('path', 325),
#              ('happily', 26),
#              ('energetic', 1),
#              ('mother', 43),
#              ('boardwalk', 24),
#              ('sea', 30),
#              ('pier', 34),
#              ('evening', 9),
#              ('pony', 13),
#              ('wintertime', 2),
#              ('atop', 37),
#              ('draft', 3),
#              ('n', 2),
#              ('daft', 1),
#              ('pull', 32),
#              ('cart', 89),
#              ('golden', 110),
#              ('sleigh', 4),
#              ('driven', 10),
#              ('coat', 269),
#              ('pulling', 110),
#              ('carriage', 19),
#              ('sled', 118),
#              ('steered', 2),
#              ('sheer', 16),
#              ('using', 64),
#              ('flat', 14),
#              ('rappels', 2),
#              ('steep', 62),
#              ('incline', 11),
#              ('vest', 98),
#              ('inside', 174),
#              ('dome', 3),
#              ('shaft', 2),
#              ('cave', 21),
#              ('shows', 33),
#              ('spelunkers', 2),
#              ('cavern', 1),
#              ('bathed', 1),
#              ('sunlight', 11),
#              ('backpackers', 2),
#              ('lay', 24),
#              ('dry', 79),
#              ('camp', 6),
#              ('gear', 117),
#              ('chalk', 17),
#              ('portrait', 7),
#              ('stream', 111),
#              ('drawing', 13),
#              ('barn', 13),
#              ('like', 104),
#              ('elaborate', 11),
#              ('illustration', 2),
#              ('deep', 88),
#              ('pile', 76),
#              ('fountain', 181),
#              ('fountains', 14),
#              ('sprayed', 25),
#              ('corgi', 7),
#              ('tunnel', 67),
#              ('course', 135),
#              ('obstacle', 125),
#              ('obedience', 3),
#              ('swimsuit', 61),
#              ('handrail', 33),
#              ('bathing', 119),
#              ('suit', 249),
#              ('spray', 37),
#              ('soaked', 12),
#              ('jet', 23),
#              ('shower', 20),
#              ('gets', 107),
#              ('underwater', 53),
#              ('headed', 16),
#              ('swims', 104),
#              ('gun', 41),
#              ('foot', 44),
#              ('aims', 5),
#              ('fireplace', 11),
#              ('new', 17),
#              ('pointed', 13),
#              ('alone', 35),
#              ('jagged', 7),
#              ('snowmobile', 13),
#              ('mid', 30),
#              ('snowmobiler', 2),
#              ('flies', 104),
#              ('rider', 185),
#              ('or', 87),
#              ('machine', 31),
#              ('pine', 23),
#              ('rural', 45),
#              ('snowmobiles', 4),
#              ('helmets', 39),
#              ('goggles', 73),
#              ('snowmobiling', 2),
#              ('helmeted', 15),
#              ('drive', 16),
#              ('atvs', 3),
#              ('heads', 49),
#              ('wheel', 66),
#              ('wheelers', 3),
#              ('empty', 50),
#              ('all', 140),
#              ('gin', 1),
#              ('airborne', 75),
#              ('quad', 6),
#              ('harvested', 2),
#              ('cornfield', 1),
#              ('s', 3),
#              ('happy', 20),
#              ('od', 1),
#              ('playfully', 32),
#              ('soccer', 580),
#              ('tucked', 1),
#              ('t', 166),
#              ('artist', 14),
#              ('paints', 12),
#              ('clouds', 32),
#              ('braids', 6),
#              ('colors', 22),
#              ('paper', 79),
#              ('cyclist', 72),
#              ('curved', 4),
#              ('aerodynamic', 2),
#              ('sharp', 21),
#              ('curve', 24),
#              ('pedaling', 3),
#              ('cows', 13),
#              ('graze', 2),
#              ('biker', 171),
#              ('fetch', 31),
#              ('pounces', 8),
#              ('cine', 1),
#              ('old', 174),
#              ('fashioned', 8),
#              ('video', 40),
#              ('steadies', 2),
#              ('aim', 4),
#              ('rosy', 1),
#              ('cheeks', 6),
#              ('lips', 17),
#              ('border', 9),
#              ('collie', 30),
#              ('audience', 38),
#              ('dug', 3),
#              ('watch', 240),
#              ('agile', 1),
#              ('onlookers', 52),
#              ('closely', 5),
#              ('smooth', 6),
#              ('stacking', 1),
#              ('against', 201),
#              ('backdrop', 9),
#              ('shoes', 91),
#              ('rappeling', 1),
#              ('headlamp', 2),
#              ('attached', 53),
#              ('snakeskin', 1),
#              ('sprays', 11),
#              ('frog', 5),
#              ('public', 48),
#              ('wood', 73),
#              ('barrior', 1),
#              ('animal', 99),
#              ('bird', 194),
#              ('seeds', 6),
#              ('sunflower', 1),
#              ('clinging', 5),
#              ('finger', 36),
#              ('wades', 12),
#              ('guided', 3),
#              ('laughs', 33),
#              ('playful', 7),
#              ('beige', 55),
#              ('torwards', 1),
#              ('outdoor', 137),
#              ('handstand', 48),
#              ('does', 232),
#              ('sheets', 5),
#              ('upside', 109),
#              ('snowboard', 88),
#              ('surfboard', 146),
#              ('bikes', 87),
#              ('traveling', 16),
#              ('worn', 5),
#              ('motorcycles', 27),
#              ('motorbikes', 7),
#              ('follow', 14),
#              ('garment', 2),
#              ('flag', 98),
#              ('crescent', 1),
#              ('moon', 5),
#              ('star', 13),
#              ('gown', 9),
#              ('muslim', 3),
#              ('helps', 29),
#              ('wave', 317),
#              ('half', 42),
#              ('naked', 52),
#              ('chair', 133),
#              ('older', 226),
#              ('back', 387),
#              ('relaxes', 12),
#              ('adobe', 1),
#              ('where', 40),
#              ('bicycles', 55),
#              ('propped', 4),
#              ('cap', 195),
#              ('close', 55),
#              ('parked', 41),
#              ('relaxing', 15),
#              ('folding', 11),
#              ('topless', 21),
#              ('slippers', 2),
#              ('navy', 14),
#              ('reclining', 2),
#              ('hauling', 1),
#              ('retrieve', 9),
#              ('mouths', 40),
#              ('tug', 44),
#              ('chew', 16),
#              ('haired', 203),
#              ('bottled', 2),
#              ('drink', 108),
#              ('tilted', 4),
#              ('spiked', 4),
#              ('party', 56),
#              ('streets', 28),
#              ('they', 121),
#              ('women', 652),
#              ('parade', 70),
#              ('neck', 49),
#              ('vegetation', 4),
#              ('filled', 52),
#              ('bushes', 37),
#              ('creating', 8),
#              ('splash', 44),
#              ('seaweed', 11),
#              ('lav', 1),
#              ('swimmers', 13),
#              ('kelp', 1),
#              ('foreground', 40),
#              ('sandals', 21),
#              ('short', 75),
#              ('sleeved', 17),
#              ('pinstripe', 2),
#              ('snows', 4),
#              ('furry', 59),
#              ('attempts', 56),
#              ('itself', 20),
#              ('self', 6),
#              ('backpacks', 32),
#              ('placed', 9),
#              ('cardboard', 27),
#              ('bus', 81),
#              ('station', 34),
#              ('bouncing', 29),
#              ('folded', 9),
#              ('beds', 3),
#              ('bedroom', 5),
#              ('snowboarder', 238),
#              ('slope', 76),
#              ('boarders', 1),
#              ('snowboarders', 12),
#              ('slopes', 7),
#              ('clothing', 130),
#              ('store', 111),
#              ('opening', 13),
#              ('stores', 8),
#              ('piece', 66),
#              ('attire', 25),
#              ('car', 429),
#              ('strip', 22),
#              ('boots', 66),
#              ('stepping', 8),
#              ('van', 16),
#              ('wear', 49),
#              ('game', 368),
#              ('plants', 43),
#              ('crossing', 58),
#              ('greenery', 6),
#              ('suspension', 1),
#              ('tropical', 12),
#              ('caution', 6),
#              ('sign', 245),
#              ('beside', 247),
#              ('bright', 124),
#              ('truck', 89),
#              ('others', 171),
#              ('helping', 27),
#              ('step', 30),
#              ('pulled', 39),
#              ('passengers', 8),
#              ('load', 2),
#              ('brightly', 38),
#              ('poses', 142),
#              ('pig', 5),
#              ('hugs', 24),
#              ('who', 216),
#              ('embracing', 8),
#              ('event', 66),
#              ('hugging', 59),
#              ('hooded', 36),
#              ('stretch', 11),
#              ('bicyclist', 64),
#              ('spandex', 3),
#              ('biking', 28),
#              ('jogging', 26),
#              ('headset', 5),
#              ('walkman', 1),
#              ('jogs', 13),
#              ('headphones', 42),
#              ('plant', 16),
#              ('corner', 59),
#              ('bicyclists', 24),
#              ('intersection', 14),
#              ('bikers', 31),
#              ('stop', 36),
#              ('town', 24),
#              ('without', 28),
#              ('guiding', 5),
#              ('wagon', 28),
#              ('escorts', 1),
#              ('leading', 21),
#              ('drawn', 4),
#              ('shetland', 1),
#              ('hits', 49),
#              ...])

# %%
# Create a word count of your tokenizer to visulize the Top 30 occuring words after text processing
get_top_words_based_on_cnt(tokenizer.word_counts,30)
#your code here

# %%
# Find the maximum length of any caption in our dataset
def calc_max_length(tensor):
    return max(len(t) for t in tensor)
# Calculates the max_length, which is used to store the attention weights
max_length = calc_max_length(train_seqs)

# %%
# Pad each vector to the max_length of the captions ^ store it to a vairable

def padding_train_sequences(train_seqs,max_length,padding_type):
  cap_vector = tf.keras.preprocessing.sequence.pad_sequences(train_seqs, padding=padding_type,maxlen=max_length)
  return cap_vector

# %%
padded_caption_vector = padding_train_sequences(train_seqs,max_length,'post')

print("The shape of Caption vector is :" + str(padded_caption_vector.shape))
# Out:
# The shape of Caption vector is :(40455, 39)

# %%
padded_caption_vector
# Out:
# array([[ 3,  2, 44, ...,  0,  0,  0],
#        [ 3,  2, 20, ...,  0,  0,  0],
#        [ 3,  2, 41, ...,  0,  0,  0],
#        ...,
#        [ 3,  2, 45, ...,  0,  0,  0],
#        [ 3,  2, 86, ...,  0,  0,  0],
#        [ 3,  2, 86, ...,  0,  0,  0]])

# %% [markdown]
# ## Pre-processing the images
#
# 1.Resize them into the shape of (299, 299)
#
# 3.Normalize the image within the range of -1 to 1, such that it is in correct format for InceptionV3.

# %%
def load_image(image_path):
    img = tf.io.read_file(image_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, (299, 299))
    img = tf.keras.applications.inception_v3.preprocess_input(img)
    return img, image_path

# %%
img1,img1_path = load_image("Flickr8k/Images/225909073_25c3c33a29.jpg")
print("Shape after resize :", img1.shape)
plt.imshow(img1)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Shape after resize : (299, 299, 3)

# %%
encode_train_set = sorted(set(all_img_vector))

feature_dict = {}

image_data_set = tf.data.Dataset.from_tensor_slices(encode_train_set)
image_data_set = image_data_set.map(load_image, num_parallel_calls=tf.data.experimental.AUTOTUNE).batch(32)

# %%
image_data_set
# Out:
# <BatchDataset shapes: ((None, 299, 299, 3), (None,)), types: (tf.float32, tf.string)>

# %% [markdown]
# ## Create the train & test data
# 1.Combine both images & captions to create the train & test dataset using tf.data.Dataset API. Create the train-test spliit using 80-20 ratio & random state = 42
#
# 2.Make sure you have done Shuffle and batch while building the dataset
#
# 3.The shape of each image in the dataset after building should be (batch_size, 299, 299, 3)
#
# 4.The shape of each caption in the dataset after building should be(batch_size, max_len)

# %%
#write your code here
image_train, image_test, caption_train, caption_test = train_test_split(all_img_vector,padded_caption_vector,test_size=0.2,random_state=42)

# %%
print("Training data for images: " + str(len(image_train)))
print("Testing data for images: " + str(len(image_test)))
print("Training data for Captions: " + str(len(caption_train)))
print("Testing data for Captions: " + str(len(caption_test)))
# Out:
# Training data for images: 32364
# Testing data for images: 8091
# Training data for Captions: 32364
# Testing data for Captions: 8091

# %%
def map_function(image_name,capt):
    image_tensor = feature_dict[image_name.decode('utf-8')]
    return image_tensor,capt

# %% [markdown]
# ## Load the pretrained Imagenet weights of Inception net V3
#
# 1.To save the memory(RAM) from getting exhausted, extract the features of thei mage using the last layer of pre-trained model. Including this as part of training will lead to higher computational time.
#
# 2.The shape of the output of this layer is 8x8x2048.
#
# 3.Use a function to extract the features of each image in the train & test dataset such that the shape of each image should be (batch_size, 8*8, 2048)

# %%
import keras
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam, RMSprop
from keras.layers.wrappers import Bidirectional
from keras.layers.merge import add
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
from tensorflow.keras.applications.inception_v3 import preprocess_input
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical

# %%
image_model = tf.keras.applications.InceptionV3(include_top=False,weights='imagenet')

new_input = image_model.input #write code here to get the input of the image_model
hidden_layer = image_model.layers[-1].output #write code here to get the output of the image_model

image_features_extract_model = keras.Model(new_input, hidden_layer) #build the final model using both input & output layer

# %%
# write your code to extract features from each image in the dataset
image_features_extract_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, None, None, 3 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, None, None, 3 96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, None, None, 3 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, None, None, 3 9216        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, None, None, 3 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, None, 3 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, None, None, 6 18432       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, None, None, 6 192         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, None, None, 6 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, None, None, 6 0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, None, None, 8 5120        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, None, None, 8 240         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, None, None, 8 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, None, None, 1 138240      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, None, None, 1 576         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, None, None, 1 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, None, None, 1 0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, None, None, 6 12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, None, None, 6 192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, None, None, 6 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, None, None, 4 9216        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, None, None, 9 55296       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, None, None, 4 144         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, None, None, 9 288         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, None, None, 4 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, None, None, 9 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, None, None, 1 0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, None, None, 6 12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, None, None, 6 76800       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, None, None, 9 82944       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, None, None, 3 6144        average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, None, None, 6 192         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, None, None, 6 192         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, None, None, 9 288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, None, None, 3 96          conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, None, None, 6 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, None, None, 6 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, None, None, 9 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, None, None, 3 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, None, None, 2 0           activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, None, None, 6 16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, None, None, 6 192         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, None, None, 6 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, None, None, 4 12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, None, None, 9 55296       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, None, None, 4 144         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, None, None, 9 288         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, None, None, 4 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, None, None, 9 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, None, None, 2 0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, None, None, 6 16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, None, None, 6 76800       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, None, None, 9 82944       activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, None, None, 6 16384       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, None, None, 6 192         conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, None, None, 6 192         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, None, None, 9 288         conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, None, None, 6 192         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, None, None, 6 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, None, None, 6 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, None, None, 9 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, None, None, 6 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, None, None, 2 0           activation_12[0][0]
#                                                                  activation_14[0][0]
#                                                                  activation_17[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, None, None, 6 18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, None, None, 6 192         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, None, None, 6 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, None, None, 4 13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, None, None, 9 55296       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, None, None, 4 144         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, None, None, 9 288         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, None, None, 4 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, None, None, 9 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, None, None, 2 0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, None, None, 6 18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, None, None, 6 76800       activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, None, None, 9 82944       activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, None, None, 6 18432       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, None, None, 6 192         conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, None, None, 6 192         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, None, None, 9 288         conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, None, None, 6 192         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, None, None, 6 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, None, None, 6 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, None, None, 9 0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, None, None, 6 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, None, None, 2 0           activation_19[0][0]
#                                                                  activation_21[0][0]
#                                                                  activation_24[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, None, None, 6 18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, None, None, 6 192         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, None, None, 6 0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, None, None, 9 55296       activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, None, None, 9 288         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, None, None, 9 0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, None, None, 3 995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, None, None, 9 82944       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, None, None, 3 1152        conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, None, None, 9 288         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, None, None, 3 0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, None, None, 9 0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, None, None, 2 0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, None, None, 7 0           activation_26[0][0]
#                                                                  activation_29[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, None, None, 1 98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, None, None, 1 384         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, None, None, 1 0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, None, None, 1 114688      activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, None, None, 1 384         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, None, None, 1 0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, None, None, 1 98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, None, None, 1 114688      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, None, None, 1 384         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, None, None, 1 384         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, None, None, 1 0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, None, None, 1 0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, None, None, 1 114688      activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, None, None, 1 114688      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, None, None, 1 384         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, None, None, 1 384         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, None, None, 1 0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, None, None, 1 0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, None, None, 7 0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, None, None, 1 147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, None, None, 1 172032      activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, None, None, 1 172032      activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, None, None, 1 147456      average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, None, None, 1 576         conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, None, None, 1 576         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, None, None, 1 576         conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, None, None, 1 576         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, None, None, 1 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, None, None, 1 0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, None, None, 1 0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, None, None, 1 0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, None, None, 7 0           activation_30[0][0]
#                                                                  activation_33[0][0]
#                                                                  activation_38[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, None, None, 1 122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, None, None, 1 480         conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, None, None, 1 0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, None, None, 1 179200      activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, None, None, 1 480         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, None, None, 1 0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, None, None, 1 122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, None, None, 1 179200      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, None, None, 1 480         conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, None, None, 1 480         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, None, None, 1 0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, None, None, 1 0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, None, None, 1 179200      activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, None, None, 1 179200      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, None, None, 1 480         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, None, None, 1 480         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, None, None, 1 0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, None, None, 1 0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, None, None, 7 0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, None, None, 1 147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, None, None, 1 215040      activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, None, None, 1 215040      activation_47[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, None, None, 1 147456      average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, None, None, 1 576         conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, None, None, 1 576         conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, None, None, 1 576         conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, None, None, 1 576         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, None, None, 1 0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, None, None, 1 0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, None, None, 1 0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, None, None, 1 0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# mixed5 (Concatenate)            (None, None, None, 7 0           activation_40[0][0]
#                                                                  activation_43[0][0]
#                                                                  activation_48[0][0]
#                                                                  activation_49[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, None, None, 1 122880      mixed5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, None, None, 1 480         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, None, None, 1 0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, None, None, 1 179200      activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, None, None, 1 480         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, None, None, 1 0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, None, None, 1 122880      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, None, None, 1 179200      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, None, None, 1 480         conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, None, None, 1 480         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, None, None, 1 0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, None, None, 1 0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, None, None, 1 179200      activation_51[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, None, None, 1 179200      activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, None, None, 1 480         conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, None, None, 1 480         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, None, None, 1 0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, None, None, 1 0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, None, None, 7 0           mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, None, None, 1 147456      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, None, None, 1 215040      activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, None, None, 1 215040      activation_57[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, None, None, 1 147456      average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, None, None, 1 576         conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, None, None, 1 576         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, None, None, 1 576         conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, None, None, 1 576         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, None, None, 1 0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, None, None, 1 0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, None, None, 1 0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, None, None, 1 0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# mixed6 (Concatenate)            (None, None, None, 7 0           activation_50[0][0]
#                                                                  activation_53[0][0]
#                                                                  activation_58[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, None, None, 1 147456      mixed6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, None, None, 1 576         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, None, None, 1 0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, None, None, 1 258048      activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, None, None, 1 576         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, None, None, 1 0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, None, None, 1 147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, None, None, 1 258048      activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, None, None, 1 576         conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, None, None, 1 576         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, None, None, 1 0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, None, None, 1 0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, None, None, 1 258048      activation_61[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, None, None, 1 258048      activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, None, None, 1 576         conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, None, None, 1 576         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, None, None, 1 0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, None, None, 1 0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, None, None, 7 0           mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, None, None, 1 147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, None, None, 1 258048      activation_62[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, None, None, 1 258048      activation_67[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, None, None, 1 147456      average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, None, None, 1 576         conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, None, None, 1 576         conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, None, None, 1 576         conv2d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, None, None, 1 576         conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, None, None, 1 0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, None, None, 1 0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, None, None, 1 0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, None, None, 1 0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# mixed7 (Concatenate)            (None, None, None, 7 0           activation_60[0][0]
#                                                                  activation_63[0][0]
#                                                                  activation_68[0][0]
#                                                                  activation_69[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, None, None, 1 576         conv2d_74[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, None, None, 1 0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, None, None, 1 0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, None, None, 3 552960      activation_70[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, None, None, 1 331776      activation_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, None, None, 3 960         conv2d_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, None, None, 1 576         conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, None, None, 3 0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, None, None, 1 0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, None, None, 7 0           mixed7[0][0]
# __________________________________________________________________________________________________
# mixed8 (Concatenate)            (None, None, None, 1 0           activation_71[0][0]
#                                                                  activation_75[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, None, None, 4 573440      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, None, None, 4 1344        conv2d_80[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, None, None, 4 0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, None, None, 3 491520      mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, None, None, 3 1548288     activation_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, None, None, 3 1152        conv2d_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, None, None, 3 1152        conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, None, None, 3 0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, None, None, 3 0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, None, None, 3 442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, None, None, 3 442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, None, None, 3 442368      activation_81[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, None, None, 3 442368      activation_81[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, None, None, 1 0           mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, None, None, 3 409600      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, None, None, 3 1152        conv2d_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, None, None, 3 1152        conv2d_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, None, None, 3 1152        conv2d_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, None, None, 3 1152        conv2d_83[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, None, None, 1 245760      average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, None, None, 3 960         conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, None, None, 3 0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, None, None, 3 0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, None, None, 3 0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, None, None, 3 0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, None, None, 1 576         conv2d_84[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, None, None, 3 0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, None, None, 7 0           activation_78[0][0]
#                                                                  activation_79[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, None, None, 7 0           activation_82[0][0]
#                                                                  activation_83[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, None, None, 1 0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, None, None, 2 0           activation_76[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate[0][0]
#                                                                  activation_84[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, None, None, 4 917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, None, None, 4 1344        conv2d_89[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, None, None, 4 0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, None, None, 3 786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, None, None, 3 1548288     activation_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, None, None, 3 1152        conv2d_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, None, None, 3 1152        conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, None, None, 3 0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, None, None, 3 0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, None, None, 3 442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, None, None, 3 442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, None, None, 3 442368      activation_90[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, None, None, 3 442368      activation_90[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, None, None, 2 0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, None, None, 3 655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, None, None, 3 1152        conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, None, None, 3 1152        conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, None, None, 3 1152        conv2d_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, None, None, 3 1152        conv2d_92[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, None, None, 1 393216      average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, None, None, 3 960         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, None, None, 3 0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, None, None, 3 0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, None, None, 3 0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, None, None, 3 0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, None, None, 1 576         conv2d_93[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, None, None, 3 0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, None, None, 7 0           activation_87[0][0]
#                                                                  activation_88[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, None, None, 7 0           activation_91[0][0]
#                                                                  activation_92[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, None, None, 1 0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, None, None, 2 0           activation_85[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  activation_93[0][0]
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 21,768,352
# Non-trainable params: 34,432
# __________________________________________________________________________________________________

# %%
from tqdm import tqdm
for image,path in tqdm(image_data_set):
    batch_features = image_features_extract_model(image)
    batch_features = tf.reshape(batch_features,(batch_features.shape[0], -1, batch_features.shape[3]))
    for batch_f, p in zip(batch_features, path):
        path_of_feature = p.numpy().decode("utf-8")
        feature_dict[path_of_feature] =  batch_f.numpy()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 253/253 [01:13<00:00,  3.44it/s]

# %%
batch_f.shape
# Out:
# TensorShape([64, 2048])

# %%
BATCH_SIZE = 32
BUFFER_SIZE = 1000
def generate_dataset(images_data, captions_data):
    
    dataset = tf.data.Dataset.from_tensor_slices((images_data, captions_data))
    dataset = dataset.shuffle(BUFFER_SIZE)

    dataset = dataset.map(lambda item1, item2: tf.numpy_function(
          map_function, [item1, item2], [tf.float32, tf.int32]),
          num_parallel_calls=tf.data.experimental.AUTOTUNE).batch(BATCH_SIZE)


    dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
    return dataset

# %%
train_dataset=generate_dataset(image_train,caption_train)
test_dataset=generate_dataset(image_test,caption_test)

# %%
sample_img_batch, sample_cap_batch = next(iter(train_dataset))
print(sample_img_batch.shape)  #(batch_size, 8*8, 2048)
print(sample_cap_batch.shape) #(batch_size,40)
# Out:
# (32, 64, 2048)
# (32, 39)

# %% [markdown]
# ## Model Building
# 1.Set the parameters
#
# 2.Build the Encoder, Attention model & Decoder

# %%
embedding_dim = 256 
units = 512
vocab_size = 5001 #top 5,000 words +1
train_num_steps = len(image_train) // BATCH_SIZE
test_num_steps = len(image_test) // BATCH_SIZE

# %% [markdown]
# ### Encoder

# %%
from tensorflow.keras import Input, layers

# %%
class Encoder(Model):
    def __init__(self,embed_dim):
        super(Encoder, self).__init__()
        #self.dense = #build your Dense layer with relu activation
        self.fc = layers.Dense(embed_dim)
        self.dropout = layers.Dropout(0.5)
        
    def call(self, features):
        #features =  # extract the features from the image shape: (batch, 8*8, embed_dim)
        features = self.fc(features)
        features = tf.nn.relu(features)
        return features

# %%
encoder=Encoder(embedding_dim)

# %% [markdown]
# ### Attention model

# %%
class Attention_model(Model):
    def __init__(self, units):
        super(Attention_model, self).__init__()
        self.W1 = layers.Dense(units)
        self.W2 = layers.Dense(units)
        self.V = layers.Dense(1)
        self.units=units

    def call(self, features, hidden):
        #features shape: (batch_size, 8*8, embedding_dim)
        # hidden shape: (batch_size, hidden_size)
        hidden_with_time_axis =  tf.expand_dims(hidden, 1)
        score = keras.activations.tanh(self.W1(features) + self.W2(hidden_with_time_axis))
        attention_weights =  keras.activations.softmax(self.V(score), axis=1)
        context_vector = attention_weights * features
        context_vector = tf.reduce_sum(context_vector, axis=1)
        

        return context_vector, attention_weights

# %%
class RNN_Decoder(Model):
    def __init__(self, embedding_dim, units, vocab_size):

        super(RNN_Decoder, self).__init__()
        self.units = units

        self.embedding = layers.Embedding(vocab_size, embedding_dim)
        self.gru = layers.GRU(self.units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
        
        self.fc1 = layers.Dense(self.units)
        self.fc2 = layers.Dense(vocab_size)

        self.attention = Attention_model(self.units)

    def call(self, x, features, hidden):
    # defining attention as a separate model
        context_vector, attention_weights = self.attention(features, hidden)

    # x shape after passing through embedding == (batch_size, 1, embedding_dim)
        x = self.embedding(x)

    # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)
        x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

    # passing the concatenated vector to the GRU
        output, state = self.gru(x)

    # shape == (batch_size, max_length, hidden_size)
        x = self.fc1(output)

    # x shape == (batch_size * max_length, hidden_size)
        x = tf.reshape(x, (-1, x.shape[2]))

    # output shape == (batch_size * max_length, vocab)
        x = self.fc2(x)

        return x, state, attention_weights

    def init_state(self, batch_size):
        return tf.zeros((batch_size, self.units))

# %% [markdown]
# ### Decoder

# %%
from tensorflow.keras.layers import LSTM, Embedding, TimeDistributed, Dense, RepeatVector, Activation, Flatten, Reshape, concatenate, Dropout, BatchNormalization, Conv2D
from tensorflow.keras import Input, layers
from tensorflow.keras import optimizers

# %%
class Decoder(Model):
    def __init__(self, embed_dim, units, vocab_size):
        super(Decoder, self).__init__()
        self.units=units
        self.attention = Attention_model(self.units)
        self.embed = layers.Embedding(vocab_size, embed_dim,mask_zero=False)
        self.gru = tf.keras.layers.GRU(self.units,return_sequences=True,return_state=True,recurrent_initializer='glorot_uniform')
        self.d1 = layers.Dense(self.units)
        self.d2 = layers.Dense(vocab_size)   
        self.dropout = Dropout(0.5)

    def call(self,x,features, hidden):
        context_vector, attention_weights = self.attention(features, hidden)
        embed = self.dropout(self.embed(x)) #shape: (batch_size, 1, embedding_dim)
        mask = self.embed.compute_mask(x)
        embed =  tf.concat([tf.expand_dims(context_vector, 1), embed], axis=-1)
        output,state = self.gru(embed,mask=mask)
        output = self.d1(output)
        output = tf.reshape(output, (-1, output.shape[2])) # shape : (batch_size * max_length, hidden_size)
        output = self.d2(output) # shape : (batch_size * max_length, vocab_size)

        return output,state, attention_weights
    
    def init_state(self, batch_size):
        return tf.zeros((batch_size, self.units))

# %%
decoder=Decoder(embedding_dim, units, vocab_size)

# %%
features=encoder(sample_img_batch)

hidden = decoder.init_state(batch_size=sample_cap_batch.shape[0])
dec_input = tf.expand_dims([tokenizer.word_index['<start>']] * sample_cap_batch.shape[0], 1)

predictions, hidden_out, attention_weights= decoder(dec_input, features, hidden)
print('Feature shape from Encoder: {}'.format(features.shape)) #(batch, 8*8, embed_dim)
print('Predcitions shape from Decoder: {}'.format(predictions.shape)) #(batch,vocab_size)
print('Attention weights shape from Decoder: {}'.format(attention_weights.shape)) #(batch, 8*8, embed_dim)
# Out:
# Feature shape from Encoder: (32, 64, 256)
# Predcitions shape from Decoder: (32, 5001)
# Attention weights shape from Decoder: (32, 64, 1)

# %% [markdown]
# ## Model training & optimization
# 1.Set the optimizer & loss object
#
# 2.Create your checkpoint path
#
# 3.Create your training & testing step functions
#
# 4.Create your loss function for the test dataset

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')

# %%
def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask

    return tf.reduce_mean(loss_)

# %%
checkpoint_path = "Flickr8K/File3/"
ckpt = tf.train.Checkpoint(encoder=encoder,
                           decoder=decoder,
                           optimizer = optimizer)
ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# %%
start_epoch = 0
if ckpt_manager.latest_checkpoint:
    start_epoch = int(ckpt_manager.latest_checkpoint.split('-')[-1])

# %%
@tf.function
def train_step(img_tensor, target):
  loss = 0
  hidden = decoder.init_state(batch_size=target.shape[0])
  dec_input = tf.expand_dims([tokenizer.word_index['<start>']] * target.shape[0], 1)

  with tf.GradientTape() as tape:
      features = encoder(img_tensor)

      for i in range(1, target.shape[1]):
          predictions, hidden, _ = decoder(dec_input, features, hidden)
          loss += loss_function(target[:, i], predictions)
          dec_input = tf.expand_dims(target[:, i], 1)
        
  avg_loss = (loss / int(target.shape[1]))

  trainable_variables = encoder.trainable_variables + decoder.trainable_variables
  gradients = tape.gradient(loss, trainable_variables)
  optimizer.apply_gradients(zip(gradients, trainable_variables))

  return loss, avg_loss

# %%
@tf.function
def test_step(img_tensor, target):
  loss = 0
  hidden = decoder.init_state(batch_size=target.shape[0])
  dec_input = tf.expand_dims([tokenizer.word_index['<start>']] * target.shape[0], 1)

  with tf.GradientTape() as tape:
      features = encoder(img_tensor)

      for i in range(1, target.shape[1]):
          predictions, hidden, _ = decoder(dec_input, features, hidden)
          loss += loss_function(target[:, i], predictions)
          dec_input = tf.expand_dims(target[:, i], 1)
        
  avg_loss = (loss / int(target.shape[1]))

  trainable_variables = encoder.trainable_variables + decoder.trainable_variables
  gradients = tape.gradient(loss, trainable_variables)
  optimizer.apply_gradients(zip(gradients, trainable_variables))

  return loss, avg_loss

# %%
def test_loss_cal(test_dataset):
    
  total_loss = 0
  for (batch, (img_tensor, target)) in enumerate(test_dataset):
    batch_loss, t_loss = test_step(img_tensor, target)
    
    total_loss += t_loss
    avg_test_loss=total_loss/test_num_steps
  return avg_test_loss

# %%
import time

# %%
loss_plot = []
test_loss_plot = []
EPOCHS = 9

best_test_loss=100
for epoch in tqdm(range(0, EPOCHS)):
    start = time.time()
    total_loss = 0

    for (batch, (img_tensor, target)) in enumerate(train_dataset):
        batch_loss, t_loss = train_step(img_tensor, target)
        total_loss += t_loss
        avg_train_loss=total_loss / train_num_steps
        
    loss_plot.append(avg_train_loss)    
    test_loss = test_loss_cal(test_dataset)
    test_loss_plot.append(test_loss)
    
    print ('For epoch: {}, the train loss is {:.3f}, & test loss is {:.3f}'.format(epoch+1,avg_train_loss,test_loss))
    print ('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
    
    if test_loss < best_test_loss:
        print('Test loss has been reduced from %.3f to %.3f' % (best_test_loss, test_loss))
        best_test_loss = test_loss
        ckpt_manager.save()
# Out:
#   0%|                                                                                                                                                                                       | 0/9 [00:00<?, ?it/s]
# For epoch: 1, the train loss is 1.191, & test loss is 1.013
# Time taken for 1 epoch 268.1399471759796 sec
#
# Test loss has been reduced from 100.000 to 1.013
#  11%|███████████████████▎                                                                                                                                                          | 1/9 [04:28<35:47, 268.46s/it]
# For epoch: 2, the train loss is 0.939, & test loss is 0.899
# Time taken for 1 epoch 360.045134305954 sec
#
# Test loss has been reduced from 1.013 to 0.899
#  22%|██████████████████████████████████████▋                                                                                                                                       | 2/9 [10:28<37:37, 322.53s/it]
# For epoch: 3, the train loss is 0.855, & test loss is 0.828
# Time taken for 1 epoch 1656.7556719779968 sec
#
# Test loss has been reduced from 0.899 to 0.828
#  33%|█████████████████████████████████████████████████████████▎                                                                                                                  | 3/9 [38:05<1:33:11, 931.88s/it]
# For epoch: 4, the train loss is 0.794, & test loss is 0.773
# Time taken for 1 epoch 305.02217960357666 sec
#
# Test loss has been reduced from 0.828 to 0.773
#  44%|█████████████████████████████████████████████████████████████████████████████▎                                                                                                | 4/9 [43:11<57:02, 684.51s/it]
# For epoch: 5, the train loss is 0.744, & test loss is 0.728
# Time taken for 1 epoch 594.2682921886444 sec
#
# Test loss has been reduced from 0.773 to 0.728
#  56%|████████████████████████████████████████████████████████████████████████████████████████████████▋                                                                             | 5/9 [53:05<43:28, 652.07s/it]
# For epoch: 6, the train loss is 0.700, & test loss is 0.685
# Time taken for 1 epoch 590.0755317211151 sec
#
# Test loss has been reduced from 0.728 to 0.685
#  67%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                                                         | 6/9 [1:02:56<31:33, 631.09s/it]
# For epoch: 7, the train loss is 0.660, & test loss is 0.648
# Time taken for 1 epoch 591.0185875892639 sec
#
# Test loss has been reduced from 0.685 to 0.648
#  78%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                                      | 7/9 [1:12:47<20:36, 618.08s/it]
# For epoch: 8, the train loss is 0.624, & test loss is 0.614
# Time taken for 1 epoch 590.2269809246063 sec
#
# Test loss has been reduced from 0.648 to 0.614
#  89%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                   | 8/9 [1:22:37<10:09, 609.31s/it]
# For epoch: 9, the train loss is 0.591, & test loss is 0.581
# Time taken for 1 epoch 591.1022322177887 sec
#
# Test loss has been reduced from 0.614 to 0.581
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [1:32:29<00:00, 616.59s/it]

# %%
plt.plot(loss_plot)
plt.plot(test_loss_plot)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Plot')
plt.show()

# %% [markdown]
# ## Model Evaluation
# 1.Define your evaluation function using greedy search
#
# 2.Define your evaluation function using beam search ( optional)
#
# 3.Test it on a sample data using BLEU score

# %% [markdown]
# ### Greedy Search

# %%
max_l = 39

# %%
def evaluate(image):
    max_length=max_l
    attention_plot = np.zeros((max_length, attention_features_shape))

    hidden = decoder.init_state(batch_size=1)

    temp_input = tf.expand_dims(load_image(image)[0], 0) #process the input image to desired format before extracting features
    img_tensor_val = image_features_extract_model(temp_input)
    img_tensor_val = tf.reshape(img_tensor_val, (img_tensor_val.shape[0], -1, img_tensor_val.shape[3]))

    features = encoder(img_tensor_val)

    dec_input = tf.expand_dims([tokenizer.word_index['<start>']], 0)
    result = []

    for i in range(max_length):
        predictions, hidden, attention_weights = decoder(dec_input, features, hidden)

        attention_plot[i] = tf.reshape(attention_weights, (-1, )).numpy()

        predicted_id = tf.argmax(predictions[0]).numpy()
        result.append(tokenizer.index_word[predicted_id])

        if tokenizer.index_word[predicted_id] == '<end>':
            return result, attention_plot,predictions

        dec_input = tf.expand_dims([predicted_id], 0)

    attention_plot = attention_plot[:len(result), :]
    return result, attention_plot,predictions

# %% [markdown]
# ### Beam Search(optional)

# %%
from PIL import Image
from PIL import ImageFont
from PIL import ImageDraw

# %%
def beam_evaluate(image, beam_index = 3):
    max_length=max_l
    start = [tokenizer.word_index['<start>']]
    result = [[start, 0.0]]

    attention_plot = np.zeros((max_length, attention_features_shape))

    hidden = decoder.init_state(batch_size=1)

    temp_input = tf.expand_dims(load_image(image)[0], 0)
    img_tensor_val = image_features_extract_model(temp_input)
    img_tensor_val = tf.reshape(img_tensor_val, (img_tensor_val.shape[0], -1, img_tensor_val.shape[3]))

    features = encoder(img_tensor_val)

    dec_input = tf.expand_dims([tokenizer.word_index['<start>']], 0)

    while len(result[0][0]) < max_length:
        i=0
        temp = []
        for s in result:
            predictions, hidden, attention_weights = decoder(dec_input, features, hidden)
            attention_plot[i] = tf.reshape(attention_weights, (-1, )).numpy()
            i=i+1
            word_preds = np.argsort(predictions[0])[-beam_index:]
          
            for w in word_preds:
                next_cap, prob = s[0][:], s[1]
                next_cap.append(w)
            
                prob += np.log(predictions[0][w])
                    
                temp.append([next_cap, prob])
        result = temp
        result = sorted(result, reverse=False, key=lambda l: l[1])
        result = result[-beam_index:]
        
        
        predicted_id = result[-1]
        pred_list = predicted_id[0]
        
        prd_id = pred_list[-1] 
        if(prd_id!=3):
            dec_input = tf.expand_dims([prd_id], 0)  
        else:
            break
    
    
    result2 = result[-1][0]
    
    intermediate_caption = [tokenizer.index_word[i] for i in result2]
    final_caption = []
    for i in intermediate_caption:
        if i != '<end>':
            final_caption.append(i)
            
        else:
            break

    attention_plot = attention_plot[:len(result), :]
    final_caption = ' '.join(final_caption[1:])
    return final_caption

# %%
def plot_attmap(caption, weights, image):

    fig = plt.figure(figsize=(10, 10))
    temp_img = np.array(Image.open(image))
    
    len_cap = len(caption)
    for cap in range(len_cap):
        weights_img = np.reshape(weights[cap], (8,8))
        weights_img = np.array(Image.fromarray(weights_img).resize((224, 224), Image.LANCZOS))
        
        ax = fig.add_subplot(len_cap//2, len_cap//2, cap+1)
        ax.set_title(caption[cap], fontsize=15)
        
        img=ax.imshow(temp_img)
        
        ax.imshow(weights_img, cmap='gist_heat', alpha=0.6,extent=img.get_extent())
        ax.axis('off')
    plt.subplots_adjust(hspace=0.2, wspace=0.2)
    plt.show()

# %%
from nltk.translate.bleu_score import sentence_bleu

# %%
def filt_text(text):
    filt=['<start>','<unk>','<end>'] 
    temp= text.split()
    [temp.remove(j) for k in filt for j in temp if k==j]
    text=' '.join(temp)
    return text

# %%
img_test1=image_test.copy()

# %%
#modifying the given code as function to run it several times by changing weights
def predicted_caption_audio(random,autoplay=False,weights=(0.5, 0.5, 0, 0)):

    cap_test=caption_test.copy()
    rid = np.random.randint(0, random)
    test_image = img_test1[rid]
    #test_image = 'Flickr8K/Images/413231421_43833a11f5.jpg'
    #real_caption = '<start> black dog is digging in the snow <end>'

    real_caption = ' '.join([tokenizer.index_word[i] for i in cap_test[rid] if i not in [0]])
    result, attention_plot,pred_test = evaluate(test_image)

    real_caption=filt_text(real_caption)      

    pred_caption=' '.join(result).rsplit(' ', 1)[0]

    real_appn = []
    real_appn.append(real_caption.split())
    reference = real_appn
    candidate = pred_caption.split()

    score = sentence_bleu(reference, candidate, weights=weights)#set your weights)
    print(f"BELU score: {score*100}")

    print ('Real Caption:', real_caption)
    print ('Prediction Caption:', pred_caption)
    plot_attmap(result, attention_plot, test_image)

    #Let's use Google Text to Speech Online API from playing the predicted caption as audio
    speech = gTTS("Predicted Caption is: "+ pred_caption,lang = 'en', slow = False) 
    speech.save('voice.mp3')
    audio_file = 'voice.mp3'
    #playsound('voice.wav')
    display.display(display.Audio(audio_file, rate=None,autoplay=autoplay))
    
    return test_image

# %%
features_shape = batch_f.shape[1]
attention_features_shape = batch_f.shape[0]

# %%
from gtts import gTTS
from playsound import playsound
from IPython import display

# %%
test_image=predicted_caption_audio(5,True,weights=(0.5,0.25,0,0))

Image.open(test_image)
# Out:
# C:\Users\subas\anaconda3\envs\tf-gpu\lib\site-packages\nltk\translate\bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# C:\Users\subas\anaconda3\envs\tf-gpu\lib\site-packages\nltk\translate\bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# BELU score: 37.647931865968445
# Real Caption: a person skiing downhill
# Prediction Caption: a person is skiing down a snowy hill
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x333 at 0x21BB327D940>

# %%
test_image=predicted_caption_audio(5,True,weights=(0.5,0.25,0,0))

Image.open(test_image)
# Out:
# C:\Users\subas\anaconda3\envs\tf-gpu\lib\site-packages\nltk\translate\bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# C:\Users\subas\anaconda3\envs\tf-gpu\lib\site-packages\nltk\translate\bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# C:\Users\subas\anaconda3\envs\tf-gpu\lib\site-packages\nltk\translate\bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# BELU score: 6.10669334877734e-76
# Real Caption: two brown dogs fight on the leafy ground
# Prediction Caption: two dogs are running through a wooded area
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x461 at 0x21BB5EAEF98>

# %%
test_image=predicted_caption_audio(5,True,weights=(0.5,0.25,0,0))

Image.open(test_image)
# Out:
# C:\Users\subas\anaconda3\envs\tf-gpu\lib\site-packages\nltk\translate\bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# C:\Users\subas\anaconda3\envs\tf-gpu\lib\site-packages\nltk\translate\bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# C:\Users\subas\anaconda3\envs\tf-gpu\lib\site-packages\nltk\translate\bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# BELU score: 4.5152254485111116e-76
# Real Caption: a large wild cat is pursuing a horse across a meadow
# Prediction Caption: a lioness is running in a field
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x333 at 0x21BB2EF4D68>

# %%
test_image=predicted_caption_audio(5,True,weights=(0.5,0.25,0,0))

Image.open(test_image)
# Out:
# C:\Users\subas\anaconda3\envs\tf-gpu\lib\site-packages\nltk\translate\bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# BELU score: 37.42031646082125
# Real Caption: a muzzled white dog is running on the grass
# Prediction Caption: a white dog with a muzzle trots through a field with a red muzzle trots on the grass
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x333 at 0x21BB60F52B0>
